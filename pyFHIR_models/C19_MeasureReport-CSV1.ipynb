# %% [markdown]
# ## 4. <a id='4_cell'></a>Create MeasureReport(MR) using CCV, Pandas and the PyFHIR models....
#
# This uses Pandas to easily upload patient data from CSV file and create  a MeasureReport (MR). The MR is then converted back the CSV to demonstrat the roundtrip.
#
# - I'm using:
#   - the [CDC/NHSN csv](https://www.cdc.gov/nhsn/pdfs/covid19/import-covid19-data-508.pdf) format with sample file `pyFHIR_models/c19_data/source/c19_data.csv` and `pyFHIR_models/c19_data/source/c19_data_min.csv` containing data for Hospital X period of several days
#   - the fema format csv based on the template referenced [here](https://www.cms.gov/files/document/32920-hospital-letter-vice-president-pence.pdf), the csv format is described in `pyFHIR_models/c19_data/source/Template_for_Daily_Hospital_COVID19_Reporting (1).xlsx` with sample file `pyFHIR_models/c19_data/source/fema_data.csv`
# - convert csv to Panda dataframe
# - create MR from each row in dataframe
#     -  based upon this [Measure definition](file:///Users/ehaas/Documents/FHIR/IG-template4/docs/Measure-cdc-covid.html)
#     -  using static metadata for now
#     -
# - Validate MR
# - Bundle the MRs Save and Post to a reference server
# - Convert bundle back to the CDC/NHSN csv format
# - Save CSV file

# %%
cd ~/pyFHIR_models # This is to make sure in right directory for Binder
# Out:
# [Errno 2] No such file or directory: '/Users/ehaas/pyFHIR_models # This is to make sure in right directory for Binder'
# /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models

# %% [markdown]
# ### import all the modules you need

# %%
from fhir_model_generator.model import measurereport, bundle, location, fhirdate, fhirreference, identifier, contactpoint, address
from json import dumps
from pandas import *
from pathlib import Path
from requests import get, post
from datetime import datetime, date, timedelta
import uuid
from IPython.display import display as Display, HTML, Markdown

# %% [markdown]
# ### Validate,Save,Bundle,POST Definitions (functions)
# -used by main process

# %%
in_path = 'c19_data/source'
out_path = 'c19_data/MR_bundle'
#in_file = 'c19_data.csv'  # max file with all fields filled out
#in_file = 'c19_data_min.csv'  # min file with only requiired fields filled out


cdc = dict(
    name = 'cdc-c19-cohort',
    in_file = 'c19_data.csv',  
    measure = "http://cdcmeasures.example.org/cdc-covid",
    scoring = "cohort",
    groups =[
    "numVent",
    "numVentUse",
    "numTotBeds",
    "numbeds",
    "numBedsOcc",
    "numICUBeds",
    "numICUBedsOcc",
    "numC19HospPats",
    "numC19MechVentPats",
    "numC19HOPats",
    "numC19OverflowPats",
    "numC19OFMechVentPats",
    "numC19Died",
    "surgicalMasks",
      ],
    )

fema_proportion = dict(
    name = 'fema-c19-proportion',
    in_file = 'fema_data.csv',   
    measure = "http://build.fhir.org/ig/AudaciousInquiry/saner-ig/fema-proportion",
    scoring = "proportion",
    groups =[
    "newPercentPositive",
    "cumulativePercentPositive",
      ],
    pops =[
    ("newTestsResulted","newPositiveC19Tests"),
    ("cumulativeTestsPerformed","cumulativePositiveC19Tests"),
      ],
    )

fema_cohort = dict(
    name = 'fema-c1-cohort',
    in_file = 'fema_data.csv',   
    measure = "http://build.fhir.org/ig/AudaciousInquiry/saner-ig/fema-cohort",
    scoring = "cohort",
    groups =[
    "newDiagnosticTests",
    "cumulativeDiagnosticTests",
    "cumulativeSpecimensRejected",
      ],
    )

mr_data_mapping = [cdc,fema_cohort,fema_proportion]

#***********************
mr_data = mr_data_mapping[0]
#************************


#ref_server ='http://hapi.fhir.org/baseR4'
ref_server ='http://test.fhir.org/r4'
headers = {
    'Accept':'application/fhir+json',
    'Content-Type':'application/fhir+json'
    }
params = dict(
          )

def isNum(num):
    return num == num and isinstance(num, int)

def validate_me(pyfhir_res):
    print(f'validating to {ref_server}...')
    r = post(f'{ref_server}/{pyfhir_res.resource_type}/$validate',
             params = params, headers = headers, data = dumps(pyfhir_res.as_json())
            )
    display(HTML(
        '<h1>Validation output</h1>'
        f'<h3>Status Code = {r.status_code}</h3>'
        f'{r.json()["text"]["div"]}'
        ))
    
   
def bundle_me(pyfhir_res, fhir_bundle=None):
    file_ts = datetime.utcnow().strftime('%Y%m%d%H%M%S%f')
    new_urn = uuid.uuid1().urn # new urn for resource
    pyfhir_res.id = new_urn[9:]
    e = bundle.BundleEntry()
    e.fullUrl = new_urn
    e.resource = pyfhir_res
    e.request = bundle.BundleEntryRequest()
    e.request.method = 'POST'
    e.request.url = pyfhir_res.resource_type
    if fhir_bundle: #add entry
        pass
    else:  # create transaction bundle
        bundle_type = 'transaction'
        bundle_id = f'{mr_data["name"]}-{file_ts}'   
        fhir_bundle = bundle.Bundle(
            dict(
                id = bundle_id,
                type = bundle_type,
                timestamp = pyfhir_res.date.as_json(),
                entry = [],
            )
        )
    fhir_bundle.entry.append(e)
    return(fhir_bundle)
    
def save_me(pyfhir_res):
    print('...........saving to file............')
    #save in out_path
    path = Path.cwd() / out_path / f'{pyfhir_res.resource_type}-{pyfhir_res.id.lower()}.json'
    path.write_text(dumps(pyfhir_res.as_json(), indent=4))
 

def post_me(pyfhir_res):
    print(f'posting to {ref_server} as transaction bundle ...')
    r = post(f'{ref_server}',
          params = params, headers = headers, data = dumps(pyfhir_res.as_json())
            )
    try:
        display(HTML(
            '<h1>Post Response</h1>'
            f'<h3>Status Code = {r.status_code}</h3><br />'
            f'<pre>Response Headers: {dumps(dict(r.headers), indent=4)}</pre>'
            f'<em>Resource Narrative</em>: {r.json()["text"]["div"]}'
            '===============================================<br /><br /><br />'
            ))
    except KeyError:
        display(HTML(
            '<h1>Post Response</h1>'
            f'<h3>Status Code = {r.status_code}</h3><br />'
            f'<pre>Response Headers: {dumps(dict(r.headers), indent=4)}</pre>'
            #f'<em>Resource Narrative</em>: {r.json()["text"]["div"]}'
            '===============================================<br /><br /><br />'
            ))

# %% [markdown]
# ### Get local file and Read into Pandas DataFrame
#
# - convert date string to date object

# %%
path = Path.cwd() / in_path / mr_data["in_file"]
df = read_csv(path)
df['collectiondate'] = to_datetime(df.collectiondate) # convert date to date-time
df['collectiondate'].dt.date
df
# Out:
#   collectiondate  numTotBeds  numbeds  numBedsOcc  numICUBeds  numICUBedsOcc  \
# 0     2020-03-30         125      100          70          20             10
# 1     2020-03-31         125      100          72          20             11
# 2     2020-04-01         125      100          74          20             12
# 3     2020-04-02         125      100          76          20             13
# 4     2020-04-03         125      100          78          20             14
# 5     2020-04-04         125      100          80          20             15
# 6     2020-04-05         125      100          82          20             16
# 7     2020-04-06         125      100          84          20             17
#
#    numVent  numVentUse  numC19HospPats  numC19MechVentPats  numC19HOPats  \
# 0       20           3              20                   3             0
# 1       20           3              21                   3             0
# 2       20           5              22                   5             0
# 3       20           5              23                   5             0
# 4       20           7              24                   7             0
# 5       20           7              25                   7             0
# 6       20           9              26                   9             0
# 7       20           9              27                   9             0
#
#    numC19OverflowPats  numC19OFMechVentPats  numC19Died surgicalMasks
# 0                   0                     0           0     4-14 days
# 1                   0                     0           0     4-14 days
# 2                   0                     0           0     4-14 days
# 3                   0                     0           0      1-3 days
# 4                   0                     0           1      1-3 days
# 5                   0                     0           0      1-3 days
# 6                   0                     0           0      1-3 days
# 7                   0                     0           1      1-3 days

# %% [markdown]
# ### Create the MR Resource
#
#  - start with fixed meta data for MR as dict

# %% [markdown]
# #### Variables

# %%
measureScore = None
my_bundle = None

f_now = fhirdate.FHIRDate(f'{datetime.utcnow().isoformat()}Z')
f_now = f_now.as_json()

# location data -fixed for now
hosp_name = 'Marin General'
state = 'CA'
county = 'Marin'
zip_code = '94965'
CMS_cert = '1234567'
CMS_cert_system = 'urn:oid:1.3.6.1.5.5.7.0.64'  # This is fake OID
NSHN_system = 'urn:oid:2.16.840.1.113883.6.277' # OID for NHSN
NSHN_OID = '2.16.840.1.113883.6.277.123'  # Fake OID
pop_code_system = "http://terminology.hl7.org/CodeSystem/measure-population"

jdn = dict(
    system ='http://terminology.hl7.org/CodeSystem/location-physical-type',
    code = 'jdn',
    display = 'Jurisdiction' ,
    )
ptype = dict(
    coding = [jdn],
    text = "US County",
            )

NSHN_identifier = dict(
    system = NSHN_system,
    value = NSHN_OID
    )

CMS_cert_identifier = dict(
    system = CMS_cert_system,
    value = CMS_cert
    )


address = dict(
type = "physical",
text = f'{county}, {state}',
district = county,
state = state,
postalCode = zip_code
)

loc = location.Location(
   dict(
   id = "loc",
   identifier = [NSHN_identifier,CMS_cert_identifier],
   name = hosp_name,
   address = address,
   physicalType = ptype,      
    )
  )


#a = get_loc("CA", "Marin")
#print(a.as_json())

mr_loc = fhirreference.FHIRReference(dict(
                reference = "#loc",
                display = f"{hosp_name} {county}, {state} {zip_code}",
            )
        )
    #print(dumps(my_mr.as_json(),indent=4))

mr_meta = dict(
            status = 'complete',
            type = 'individual',
            measure = mr_data["measure"],
            subject = mr_loc.as_json(), # initially same as reporter
            date = f_now,
            reporter = mr_loc.as_json(),  # initially now same as subject
        )

# %% [markdown]
# #### Functions for defining subelements

# %%
def get_ms_ext(ms_code):
    extension = dict(
    url = 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType',
    valueCodeableConcept = {'text': ms_code},
    )
    return(dict(
        extension = [extension],
        )
    )


def get_pop(i, pop, pop_code_value, id=False):
    pop_coding = dict(
        system = pop_code_system,
        code = pop_code_value,
            ) 
    pop_code = dict(
    coding = [pop_coding]
    )
    mr_population =  dict(
    id = f'{pop}.{pop_code_value}' if id else None,
    code = pop_code,
    count = getattr(i, pop, None) if isinstance(getattr(i, pop, None), int) else None, # if integer
    )
    return(mr_population)

def get_score(i, num, denom):
    return(dict(
        value = getattr(i, num, None)/getattr(i, denom, None),
        unit ="%",
        system = "http://unitsofmeasure.org",
        code = "%",
            )
          )

# %% [markdown]
# #### Main
#
# - iterate over the dataframe row
# - add in period
# - groups
# - populations and counts
# - and measurescores
# - update with contained location for county and state
# - validate
# - bundle
# - validate
# - post
# - save

# %%
for i in df.itertuples(index=True):
    print(f'***************** row = {i.Index} *******************')
    mr_period = dict(
        start = str(i.collectiondate.date()),
        end = str(i.collectiondate.date())
    )
    mr_meta.update(dict(period = mr_period))
    mr_groups = []
    for group_index, group in enumerate(mr_data["groups"]):
        group_population = []
        if mr_data['scoring'] == "cohort":
            pop = group
            group_population.append(get_pop(i, pop, pop_code_value = "initial-population"))
            measureScore = get_ms_ext(getattr(i, pop, None)) if isinstance(getattr(i, pop, None), str) else None
        if mr_data['scoring'] == "proportion":
            group_pops = mr_data["pops"][group_index]
            ipop = group_pops[0]
            group_population.append(get_pop(i, ipop, pop_code_value = "initial-population", id=True))
            group_population.append(get_pop(i, ipop, pop_code_value = "denominator", id=True))
            num = group_pops[1]
            group_population.append(get_pop(i, num, pop_code_value = "numerator", id=True))
            measureScore = get_score(i, num, ipop)
        mr_group = dict(
            code = {'text': group},
            population = group_population,
            measureScore = measureScore if measureScore else None,
            )
        print(mr_group)
        mr_groups.append(mr_group)
    mr_meta.update(dict(group = mr_groups))
    my_mr = measurereport.MeasureReport(mr_meta, strict=False)  # initialize MR instance
    my_mr.contained = [loc]
    print(dumps(my_mr.as_json(),indent=4))
    validate_me(my_mr)
    my_bundle = bundle_me(my_mr,my_bundle) # as transaction
print(dumps(my_bundle.as_json(),indent=4))
validate_me(my_bundle)
save_me(my_bundle)
post_me(my_bundle)
# Out:
# ***************** row = 0 *******************
# {'code': {'text': 'numVent'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 20}], 'measureScore': None}
# {'code': {'text': 'numVentUse'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 3}], 'measureScore': None}
# {'code': {'text': 'numTotBeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 125}], 'measureScore': None}
# {'code': {'text': 'numbeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 100}], 'measureScore': None}
# {'code': {'text': 'numBedsOcc'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 70}], 'measureScore': None}
# {'code': {'text': 'numICUBeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 20}], 'measureScore': None}
# {'code': {'text': 'numICUBedsOcc'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 10}], 'measureScore': None}
# {'code': {'text': 'numC19HospPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 20}], 'measureScore': None}
# {'code': {'text': 'numC19MechVentPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 3}], 'measureScore': None}
# {'code': {'text': 'numC19HOPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19OverflowPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19OFMechVentPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19Died'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'surgicalMasks'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': None}], 'measureScore': {'extension': [{'url': 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType', 'valueCodeableConcept': {'text': '4-14 days'}}]}}
# {
#     "resourceType": "MeasureReport",
#     "contained": [
#         {
#             "resourceType": "Location",
#             "id": "loc",
#             "identifier": [
#                 {
#                     "system": "urn:oid:2.16.840.1.113883.6.277",
#                     "value": "2.16.840.1.113883.6.277.123"
#                 },
#                 {
#                     "system": "urn:oid:1.3.6.1.5.5.7.0.64",
#                     "value": "1234567"
#                 }
#             ],
#             "name": "Marin General",
#             "address": {
#                 "type": "physical",
#                 "text": "Marin, CA",
#                 "district": "Marin",
#                 "state": "CA",
#                 "postalCode": "94965"
#             },
#             "physicalType": {
#                 "coding": [
#                     {
#                         "system": "http://terminology.hl7.org/CodeSystem/location-physical-type",
#                         "code": "jdn",
#                         "display": "Jurisdiction"
#                     }
#                 ],
#                 "text": "US County"
#             }
#         }
#     ],
#     "status": "complete",
#     "type": "individual",
#     "measure": "http://cdcmeasures.example.org/cdc-covid",
#     "subject": {
#         "reference": "#loc",
#         "display": "Marin General Marin, CA 94965"
#     },
#     "date": "2020-04-12T02:20:29.262932Z",
#     "reporter": {
#         "reference": "#loc",
#         "display": "Marin General Marin, CA 94965"
#     },
#     "period": {
#         "start": "2020-03-30",
#         "end": "2020-03-30"
#     },
#     "group": [
#         {
#             "code": {
#                 "text": "numVent"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 20
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numVentUse"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 3
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numTotBeds"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 125
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numbeds"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 100
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numBedsOcc"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 70
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numICUBeds"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 20
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numICUBedsOcc"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 10
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19HospPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 20
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19MechVentPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 3
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19HOPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19OverflowPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19OFMechVentPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19Died"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "surgicalMasks"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     }
#                 }
#             ],
#             "measureScore": {
#                 "extension": [
#                     {
#                         "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType",
#                         "valueCodeableConcept": {
#                             "text": "4-14 days"
#                         }
#                     }
#                 ]
#             }
#         }
#     ]
# }
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 400</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>error</td><td>MeasureReport</td><td>If the resource is contained in another resource, it SHALL be referred to from elsewhere in the resource or SHALL refer to the containing resource (Error performing +: left and right operand have incompatible or illegal types (string, http://hl7.org/fhirpath/System.String)) contained.where((('#'+id in (%resource.descendants().reference | %resource.descendants().as(canonical) | %resource.descendants().as(uri) | %resource.descendants().as(url))) or descendants().where(reference = '#').exists() or descendants().where(as(canonical) = '#').exists() or descendants().where(as(canonical) = '#').exists()).not()).trace('unmatched', id).empty()</td><td/><td>invariant</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.subject</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.reporter</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.group[13].measureScore.extension</td><td>Element is unknown or does not match any slice (url="http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType") for profile http://hl7.org/fhir/StructureDefinition/Quantity</td><td/><td>invalid</td></tr></table></div>
# ***************** row = 1 *******************
# {'code': {'text': 'numVent'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 20}], 'measureScore': None}
# {'code': {'text': 'numVentUse'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 3}], 'measureScore': None}
# {'code': {'text': 'numTotBeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 125}], 'measureScore': None}
# {'code': {'text': 'numbeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 100}], 'measureScore': None}
# {'code': {'text': 'numBedsOcc'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 72}], 'measureScore': None}
# {'code': {'text': 'numICUBeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 20}], 'measureScore': None}
# {'code': {'text': 'numICUBedsOcc'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 11}], 'measureScore': None}
# {'code': {'text': 'numC19HospPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 21}], 'measureScore': None}
# {'code': {'text': 'numC19MechVentPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 3}], 'measureScore': None}
# {'code': {'text': 'numC19HOPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19OverflowPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19OFMechVentPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19Died'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'surgicalMasks'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': None}], 'measureScore': {'extension': [{'url': 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType', 'valueCodeableConcept': {'text': '4-14 days'}}]}}
# {
#     "resourceType": "MeasureReport",
#     "contained": [
#         {
#             "resourceType": "Location",
#             "id": "loc",
#             "identifier": [
#                 {
#                     "system": "urn:oid:2.16.840.1.113883.6.277",
#                     "value": "2.16.840.1.113883.6.277.123"
#                 },
#                 {
#                     "system": "urn:oid:1.3.6.1.5.5.7.0.64",
#                     "value": "1234567"
#                 }
#             ],
#             "name": "Marin General",
#             "address": {
#                 "type": "physical",
#                 "text": "Marin, CA",
#                 "district": "Marin",
#                 "state": "CA",
#                 "postalCode": "94965"
#             },
#             "physicalType": {
#                 "coding": [
#                     {
#                         "system": "http://terminology.hl7.org/CodeSystem/location-physical-type",
#                         "code": "jdn",
#                         "display": "Jurisdiction"
#                     }
#                 ],
#                 "text": "US County"
#             }
#         }
#     ],
#     "status": "complete",
#     "type": "individual",
#     "measure": "http://cdcmeasures.example.org/cdc-covid",
#     "subject": {
#         "reference": "#loc",
#         "display": "Marin General Marin, CA 94965"
#     },
#     "date": "2020-04-12T02:20:29.262932Z",
#     "reporter": {
#         "reference": "#loc",
#         "display": "Marin General Marin, CA 94965"
#     },
#     "period": {
#         "start": "2020-03-31",
#         "end": "2020-03-31"
#     },
#     "group": [
#         {
#             "code": {
#                 "text": "numVent"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 20
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numVentUse"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 3
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numTotBeds"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 125
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numbeds"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 100
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numBedsOcc"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 72
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numICUBeds"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 20
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numICUBedsOcc"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 11
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19HospPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 21
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19MechVentPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 3
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19HOPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19OverflowPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19OFMechVentPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19Died"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "surgicalMasks"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     }
#                 }
#             ],
#             "measureScore": {
#                 "extension": [
#                     {
#                         "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType",
#                         "valueCodeableConcept": {
#                             "text": "4-14 days"
#                         }
#                     }
#                 ]
#             }
#         }
#     ]
# }
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 400</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>error</td><td>MeasureReport</td><td>If the resource is contained in another resource, it SHALL be referred to from elsewhere in the resource or SHALL refer to the containing resource (Error performing +: left and right operand have incompatible or illegal types (string, http://hl7.org/fhirpath/System.String)) contained.where((('#'+id in (%resource.descendants().reference | %resource.descendants().as(canonical) | %resource.descendants().as(uri) | %resource.descendants().as(url))) or descendants().where(reference = '#').exists() or descendants().where(as(canonical) = '#').exists() or descendants().where(as(canonical) = '#').exists()).not()).trace('unmatched', id).empty()</td><td/><td>invariant</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.subject</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.reporter</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.group[13].measureScore.extension</td><td>Element is unknown or does not match any slice (url="http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType") for profile http://hl7.org/fhir/StructureDefinition/Quantity</td><td/><td>invalid</td></tr></table></div>
# ***************** row = 2 *******************
# {'code': {'text': 'numVent'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 20}], 'measureScore': None}
# {'code': {'text': 'numVentUse'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 5}], 'measureScore': None}
# {'code': {'text': 'numTotBeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 125}], 'measureScore': None}
# {'code': {'text': 'numbeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 100}], 'measureScore': None}
# {'code': {'text': 'numBedsOcc'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 74}], 'measureScore': None}
# {'code': {'text': 'numICUBeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 20}], 'measureScore': None}
# {'code': {'text': 'numICUBedsOcc'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 12}], 'measureScore': None}
# {'code': {'text': 'numC19HospPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 22}], 'measureScore': None}
# {'code': {'text': 'numC19MechVentPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 5}], 'measureScore': None}
# {'code': {'text': 'numC19HOPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19OverflowPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19OFMechVentPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19Died'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'surgicalMasks'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': None}], 'measureScore': {'extension': [{'url': 'http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType', 'valueCodeableConcept': {'text': '4-14 days'}}]}}
# {
#     "resourceType": "MeasureReport",
#     "contained": [
#         {
#             "resourceType": "Location",
#             "id": "loc",
#             "identifier": [
#                 {
#                     "system": "urn:oid:2.16.840.1.113883.6.277",
#                     "value": "2.16.840.1.113883.6.277.123"
#                 },
#                 {
#                     "system": "urn:oid:1.3.6.1.5.5.7.0.64",
#                     "value": "1234567"
#                 }
#             ],
#             "name": "Marin General",
#             "address": {
#                 "type": "physical",
#                 "text": "Marin, CA",
#                 "district": "Marin",
#                 "state": "CA",
#                 "postalCode": "94965"
#             },
#             "physicalType": {
#                 "coding": [
#                     {
#                         "system": "http://terminology.hl7.org/CodeSystem/location-physical-type",
#                         "code": "jdn",
#                         "display": "Jurisdiction"
#                     }
#                 ],
#                 "text": "US County"
#             }
#         }
#     ],
#     "status": "complete",
#     "type": "individual",
#     "measure": "http://cdcmeasures.example.org/cdc-covid",
#     "subject": {
#         "reference": "#loc",
#         "display": "Marin General Marin, CA 94965"
#     },
#     "date": "2020-04-12T02:20:29.262932Z",
#     "reporter": {
#         "reference": "#loc",
#         "display": "Marin General Marin, CA 94965"
#     },
#     "period": {
#         "start": "2020-04-01",
#         "end": "2020-04-01"
#     },
#     "group": [
#         {
#             "code": {
#                 "text": "numVent"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 20
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numVentUse"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 5
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numTotBeds"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 125
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numbeds"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 100
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numBedsOcc"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 74
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numICUBeds"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 20
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numICUBedsOcc"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 12
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19HospPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 22
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19MechVentPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 5
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19HOPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19OverflowPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19OFMechVentPats"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "numC19Died"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     },
#                     "count": 0
#                 }
#             ]
#         },
#         {
#             "code": {
#                 "text": "surgicalMasks"
#             },
#             "population": [
#                 {
#                     "code": {
#                         "coding": [
#                             {
#                                 "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                 "code": "initial-population"
#                             }
#                         ]
#                     }
#                 }
#             ],
#             "measureScore": {
#                 "extension": [
#                     {
#                         "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType",
#                         "valueCodeableConcept": {
#                             "text": "4-14 days"
#                         }
#                     }
#                 ]
#             }
#         }
#     ]
# }
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 400</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>error</td><td>MeasureReport</td><td>If the resource is contained in another resource, it SHALL be referred to from elsewhere in the resource or SHALL refer to the containing resource (Error performing +: left and right operand have incompatible or illegal types (string, http://hl7.org/fhirpath/System.String)) contained.where((('#'+id in (%resource.descendants().reference | %resource.descendants().as(canonical) | %resource.descendants().as(uri) | %resource.descendants().as(url))) or descendants().where(reference = '#').exists() or descendants().where(as(canonical) = '#').exists() or descendants().where(as(canonical) = '#').exists()).not()).trace('unmatched', id).empty()</td><td/><td>invariant</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.subject</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.reporter</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.group[13].measureScore.extension</td><td>Element is unknown or does not match any slice (url="http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType") for profile http://hl7.org/fhir/StructureDefinition/Quantity</td><td/><td>invalid</td></tr></table></div>
# ***************** row = 3 *******************
# {'code': {'text': 'numVent'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 20}], 'measureScore': None}
# {'code': {'text': 'numVentUse'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 5}], 'measureScore': None}
# {'code': {'text': 'numTotBeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 125}], 'measureScore': None}
# {'code': {'text': 'numbeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 100}], 'measureScore': None}
# {'code': {'text': 'numBedsOcc'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 76}], 'measureScore': None}
# {'code': {'text': 'numICUBeds'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 20}], 'measureScore': None}
# {'code': {'text': 'numICUBedsOcc'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 13}], 'measureScore': None}
# {'code': {'text': 'numC19HospPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 23}], 'measureScore': None}
# {'code': {'text': 'numC19MechVentPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 5}], 'measureScore': None}
# {'code': {'text': 'numC19HOPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19OverflowPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19OFMechVentPats'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# {'code': {'text': 'numC19Died'}, 'population': [{'id': None, 'code': {'coding': [{'system': 'http://terminology.hl7.org/CodeSystem/measure-population', 'code': 'initial-population'}]}, 'count': 0}], 'measureScore': None}
# ...
#                             "text": "numbeds"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 100
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "numBedsOcc"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 84
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "numICUBeds"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "numICUBedsOcc"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 17
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "numC19HospPats"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 27
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "numC19MechVentPats"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 9
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "numC19HOPats"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "numC19OverflowPats"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "numC19OFMechVentPats"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "numC19Died"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 1
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "surgicalMasks"
#                         },
#                         "population": [
#                             {
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 }
#                             }
#                         ],
#                         "measureScore": {
#                             "extension": [
#                                 {
#                                     "url": "http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType",
#                                     "valueCodeableConcept": {
#                                         "text": "1-3 days"
#                                     }
#                                 }
#                             ]
#                         }
#                     }
#                 ]
#             },
#             "request": {
#                 "method": "POST",
#                 "url": "MeasureReport"
#             }
#         }
#     ]
# }
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 400</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>error</td><td>Bundle.entry[0].resource</td><td>If the resource is contained in another resource, it SHALL be referred to from elsewhere in the resource or SHALL refer to the containing resource (Error performing +: left and right operand have incompatible or illegal types (string, http://hl7.org/fhirpath/System.String)) contained.where((('#'+id in (%resource.descendants().reference | %resource.descendants().as(canonical) | %resource.descendants().as(uri) | %resource.descendants().as(url))) or descendants().where(reference = '#').exists() or descendants().where(as(canonical) = '#').exists() or descendants().where(as(canonical) = '#').exists()).not()).trace('unmatched', id).empty()</td><td/><td>invariant</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>error</td><td>Bundle.entry[0].resource.subject</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>Bundle.entry[0].resource.reporter</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>Bundle.entry[0].resource.group[13].measureScore.extension</td><td>Element is unknown or does not match any slice (url="http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType") for profile http://hl7.org/fhir/StructureDefinition/Quantity</td><td/><td>invalid</td></tr><tr><td>error</td><td>Bundle.entry[1].resource</td><td>If the resource is contained in another resource, it SHALL be referred to from elsewhere in the resource or SHALL refer to the containing resource (Error performing +: left and right operand have incompatible or illegal types (string, http://hl7.org/fhirpath/System.String)) contained.where((('#'+id in (%resource.descendants().reference | %resource.descendants().as(canonical) | %resource.descendants().as(uri) | %resource.descendants().as(url))) or descendants().where(reference = '#').exists() or descendants().where(as(canonical) = '#').exists() or descendants().where(as(canonical) = '#').exists()).not()).trace('unmatched', id).empty()</td><td/><td>invariant</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>error</td><td>Bundle.entry[1].resource.subject</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>Bundle.entry[1].resource.reporter</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>Bundle.entry[1].resource.group[13].measureScore.extension</td><td>Element is unknown or does not match any slice (url="http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType") for profile http://hl7.org/fhir/StructureDefinition/Quantity</td><td/><td>invalid</td></tr><tr><td>error</td><td>Bundle.entry[2].resource</td><t ...
# ...........saving to file............
# posting to http://test.fhir.org/r4 as transaction bundle ...
# <h1>Post Response</h1><h3>Status Code = 400</h3><br /><pre>Response Headers: {
#     "Connection": "close",
#     "Content-Type": "application/fhir+json",
#     "Content-Length": "3947",
#     "Cache-control": "public, max-age=600",
#     "Date": "Sun, 12 Apr 2020 02:20:38 GMT",
#     "Pragma": "no-cache",
#     "X-Request-Id": "152-328580",
#     "Access-Control-Allow-Origin": "*",
#     "Access-Control-Expose-Headers": "Content-Location, Location",
#     "Access-Control-Allow-Methods": "GET, POST, PUT, PATCH, DELETE",
#     "X-GDPR-Disclosure": "All access to this server is logged as AuditEvent Resources, and these store your ip address (and logged in user, if one exists). Also, your IP address is logged with Google Analytics for building geomaps of server usage. Your continued use of the API constitutes agreement to these terms. See [link] for erasure requests",
#     "Server": "Health Intersections FHIR Server"
# }</pre><em>Resource Narrative</em>: <div><p><b>Operation Outcome for :Create Resource MeasureReport/558 ()</b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>error</td><td>MeasureReport</td><td>If the resource is contained in another resource, it SHALL be referred to from elsewhere in the resource or SHALL refer to the containing resource (Error performing +: left and right operand have incompatible or illegal types (string, http://hl7.org/fhirpath/System.String)) contained.where((('#'+id in (%resource.descendants().reference | %resource.descendants().as(canonical) | %resource.descendants().as(uri) | %resource.descendants().as(url))) or descendants().where(reference = '#').exists() or descendants().where(as(canonical) = '#').exists() or descendants().where(as(canonical) = '#').exists()).not()).trace('unmatched', id).empty()</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.subject</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.reporter</td><td>SHALL have a contained resource if a local reference is provided (url: loc) (Unknown fixed constant "%rootResource") reference.startsWith('#').not() or (reference.substring(1).trace('url') in %rootResource.contained.id.trace('ids'))</td><td/><td>invariant</td></tr><tr><td>error</td><td>MeasureReport.group[13].measureScore.extension</td><td>Element is unknown or does not match any slice (url="http://hl7.org/fhir/us/davinci-deqm/StructureDefinition/extension-alternateScoreType") for profile http://hl7.org/fhir/StructureDefinition/Quantity</td><td/><td>invalid</td></tr></table></div>===============================================<br /><br /><br />

# %% [markdown]
# ### Convert back to CSV
#
# - create new Dataframe based on the old one ( this is cheating )
# - For each bundle add row to Dataframe
# - save as CSV

# %%
new_df = df.iloc[0:0,:].copy()
for i, entry in enumerate(my_bundle.entry):
    new_row = {}
    mr = entry.resource
    new_row['collectiondate']= mr.period.start.as_json()
    # add county, state if fema
    for group in mr.group:
        try:
            new_row[group.code.text]= group.measureScore.value #Measure Score for proportions...
        except AttributeError:
            pass
        except TypeError:
            pass

        for gpop in group.population:
            if gpop.id:
                new_row[gpop.id]= gpop.count
            new_row[group.code.text]= gpop.count            
    new_df = new_df.append(new_row, ignore_index=True)

new_df['collectiondate'] = to_datetime(new_df.collectiondate) # convert date to date-time
new_df['collectiondate'] = new_df['collectiondate'].dt.strftime('%m/%d/%Y')
new_df.fillna(value=np.nan, inplace=True) # # convert None to NaN
new_df
# Out:
#   collectiondate  numTotBeds  numbeds  numBedsOcc  numICUBeds  numICUBedsOcc  \
# 0     03/30/2020         125      100          70          20             10
# 1     03/31/2020         125      100          72          20             11
# 2     04/01/2020         125      100          74          20             12
# 3     04/02/2020         125      100          76          20             13
# 4     04/03/2020         125      100          78          20             14
# 5     04/04/2020         125      100          80          20             15
# 6     04/05/2020         125      100          82          20             16
# 7     04/06/2020         125      100          84          20             17
#
#    numVent  numVentUse  numC19HospPats  numC19MechVentPats  numC19HOPats  \
# 0       20           3              20                   3             0
# 1       20           3              21                   3             0
# 2       20           5              22                   5             0
# 3       20           5              23                   5             0
# 4       20           7              24                   7             0
# 5       20           7              25                   7             0
# 6       20           9              26                   9             0
# 7       20           9              27                   9             0
#
#    numC19OverflowPats  numC19OFMechVentPats  numC19Died  surgicalMasks
# 0                   0                     0           0            NaN
# 1                   0                     0           0            NaN
# 2                   0                     0           0            NaN
# 3                   0                     0           0            NaN
# 4                   0                     0           1            NaN
# 5                   0                     0           0            NaN
# 6                   0                     0           0            NaN
# 7                   0                     0           1            NaN

# %%
path = Path.cwd() / out_path / f'{my_bundle.resource_type}-{my_bundle.id.lower()}.csv'
print(f'....saving {my_bundle.resource_type}-{my_bundle.id.lower()}.csv to file ....')
new_df.to_csv(path, index=False)
# Out:
# ....saving Bundle-cdc-c19-cohort-20200412022031686768.csv to file ....
