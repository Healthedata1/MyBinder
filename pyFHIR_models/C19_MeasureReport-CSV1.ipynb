# %% [markdown]
# ## 4. <a id='4_cell'></a>Create MeasureReport(MR) using CCV, Pandas and the PyFHIR models....
#
# This uses Pandas to easily upload patient data from CSV file and create  a MeasureReport (MR). The MR is then converted back the CSV to demonstrat the roundtrip.
#
# - I'm using the [CDC/NHSN csv](https://www.cdc.gov/nhsn/pdfs/covid19/import-covid19-data-508.pdf) format with sample file `c19_data.csv` containing data for Hospital X period of several days
# - convert csv to Panda dataframe
# - create MR from each row in dataframe
#     -  based upon this [Measure definition](file:///Users/ehaas/Documents/FHIR/IG-template4/docs/Measure-cdc-covid.html)
#     -  using static metadata for now
#     -
# - Validate MR
# - Bundle the MRs Save and Post to a reference server
# - Convert bundle back to the CDC/NHSN csv format
# - Save CSV file

# %%
cd ~/pyFHIR_models # This is to make sure in right directory for Binder
# Out:
# [Errno 2] No such file or directory: '/Users/ehaas/pyFHIR_models # This is to make sure in right directory for Binder'
# /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models

# %% [markdown]
# ### import all the modules you need

# %%
from fhir_model_generator.model import measurereport, bundle, fhirdate, fhirreference, group, patient, identifier, contactpoint, address
from json import dumps
from pandas import *
from pathlib import Path
from requests import get, post
from datetime import datetime, date, timedelta
import uuid
from IPython.display import display as Display, HTML, Markdown

# %% [markdown]
# ### Validate, Save and Bundle Functions

# %%
#ref_server ='http://hapi.fhir.org/baseR4'
ref_server ='http://test.fhir.org/r4'
headers = {
    'Accept':'application/fhir+json',
    'Content-Type':'application/fhir+json'
    }
params = dict(
          )
out_path = 'MR_bundle'

def validate_me(pyfhir_res):
    print(f'validating to {ref_server}...')
    r = post(f'{ref_server}/{pyfhir_res.resource_type}/$validate',
             params = params, headers = headers, data = dumps(pyfhir_res.as_json())
            )
    display(HTML(
        '<h1>Validation output</h1>'
        f'<h3>Status Code = {r.status_code}</h3>'
        f'{r.json()["text"]["div"]}'
        ))
    
   
def bundle_me(pyfhir_res, fhir_bundle=None):
    file_ts = datetime.utcnow().strftime('%Y%m%d%H%M%S%f')
    new_urn = uuid.uuid1().urn # new urn for resource
    pyfhir_res.id = new_urn[9:]
    e = bundle.BundleEntry()
    e.fullUrl = new_urn
    e.resource = pyfhir_res
    e.request = bundle.BundleEntryRequest()
    e.request.method = 'POST'
    e.request.url = pyfhir_res.resource_type
    if fhir_bundle: #add entry
        pass
    else:  # create transaction bundle
        bundle_type = 'transaction'
        bundle_id = f'cdc-c19-groups-{file_ts}'   
        fhir_bundle = bundle.Bundle(
            dict(
                id = bundle_id,
                type = bundle_type,
                timestamp = pyfhir_res.date.as_json(),
                entry = [],
            )
        )
    fhir_bundle.entry.append(e)
    return(fhir_bundle)
    
def save_me(pyfhir_res):
    print('...........saving to file............')
    #save in out_path
    path = Path.cwd() / out_path / f'{pyfhir_res.resource_type}-{pyfhir_res.id.lower()}.json'
    path.write_text(dumps(pyfhir_res.as_json(), indent=4))
 

def post_me(pyfhir_res):
    print(f'posting to {ref_server} as transaction bundle ...')
    r = post(f'{ref_server}',
          params = params, headers = headers, data = dumps(pyfhir_res.as_json())
            )
    try:
        display(HTML(
            '<h1>Post Response</h1>'
            f'<h3>Status Code = {r.status_code}</h3><br />'
            f'<pre>Response Headers: {dumps(dict(r.headers), indent=4)}</pre>'
            f'<em>Resource Narrative</em>: {r.json()["text"]["div"]}'
            '===============================================<br /><br /><br />'
            ))
    except KeyError:
        display(HTML(
            '<h1>Post Response</h1>'
            f'<h3>Status Code = {r.status_code}</h3><br />'
            f'<pre>Response Headers: {dumps(dict(r.headers), indent=4)}</pre>'
            #f'<em>Resource Narrative</em>: {r.json()["text"]["div"]}'
            '===============================================<br /><br /><br />'
            ))

# %%
in_file = 'c19_data.csv'
df = read_csv(in_file)
df['collectiondate'] = to_datetime(df.collectiondate) # convert date to date-time
df['collectiondate'].dt.date
df
# Out:
#   collectiondate  numTotBeds  numbeds  numBedsOcc  numICUBeds  numICUBedsOcc  \
# 0     2020-03-30         125      100          70          20             10
# 1     2020-03-31         125      100          72          20             11
# 2     2020-04-01         125      100          74          20             12
# 3     2020-04-02         125      100          76          20             13
# 4     2020-04-03         125      100          78          20             14
# 5     2020-04-04         125      100          80          20             15
# 6     2020-04-05         125      100          82          20             16
# 7     2020-04-06         125      100          84          20             17
#
#    numVent  numVentUse  numC19HospPats  numC19MechVentPats  numC19HOPats  \
# 0       20           3              20                   3             0
# 1       20           3              21                   3             0
# 2       20           5              22                   5             0
# 3       20           5              23                   5             0
# 4       20           7              24                   7             0
# 5       20           7              25                   7             0
# 6       20           9              26                   9             0
# 7       20           9              27                   9             0
#
#    numC19OverflowPats  numC19OFMechVentPats  numC19Died
# 0                   0                     0           0
# 1                   0                     0           0
# 2                   0                     0           0
# 3                   0                     0           0
# 4                   0                     0           1
# 5                   0                     0           0
# 6                   0                     0           0
# 7                   0                     0           1

# %% [markdown]
# ### Initialize the MR Resource
#
#  - start with fixed meta data as dict
#  - iterate over the dataframe rows add in period and scores

# %%
# ********* Globals ***************

f_now = fhirdate.FHIRDate(f'{datetime.utcnow().isoformat()}Z')
f_now = f_now.as_json()

IP = {
        "coding" : [
          {
            "system" : "http://terminology.hl7.org/CodeSystem/measure-population",
            "code" : "initial-population"
          }
        ],
      }

cdc_c19_groups = {
  "Hospital Bed/ICU Capacity": [
    "numVent",
    "numVentUse"
  ],
  "Hospital Ventilator Capacity": [
    "numTotBeds",
    "numbeds",
    "numBedsOcc",
    "numICUBeds",
    "numICUBedsOcc"
  ],
  "Patient Impact": [
    "numC19HospPats",
    "numC19MechVentPats",
    "numC19HOPats",
    "numC19OverflowPats",
    "numC19OFMechVentPats",
    "numC19Died"
  ]
}

cdc_c19_measure = "http://cdcmeasures.example.org/modules/covid19/20200331/numTotBeds"
NSHN_system = 'urn:oid:2.16.840.1.113883.6.277' # OID for NHSN
NSHN_OID = '2.16.840.1.113883.6.277.123'  # Fake OID


mr_loc_identifier = dict(
    system = NSHN_system,
    value = NSHN_OID
    )

mr_loc = dict(
  identifier = mr_loc_identifier
    )

mr_meta = dict(
            status = 'complete',
            type = 'individual',
            measure = cdc_c19_measure,
            subject = mr_loc,
            date = f_now,
            reporter = mr_loc,  # for now same as subject
            group = mr_groups
        )

# ********* Globals ***************

my_bundle = None
for i in df.itertuples(index=True):
    print(f'***************** row = {i.Index} *******************')
    mr_period = dict(
        start = str(i.collectiondate.date()),
        end = str(i.collectiondate.date())
    )
    mr_meta.update(dict(period = mr_period))
    mr_groups = []
    for k,v in cdc_c19_groups.items():        
        mr_populations=[]
        for j in v:
            #print(k,j,getattr(i, j)) if getattr(i, j) else print('k,j,"NULL"')
            mr_population =  dict(
                id = j,
                code = IP,
                count = getattr(i, j),
                )
            mr_populations.append(mr_population)             
        mr_group = dict(
            code = {'text':k},
            population = mr_populations,      
            )
        mr_groups.append(mr_group)
    mr_meta.update(dict(group = mr_groups))
    my_mr = measurereport.MeasureReport(mr_meta, strict=False)  # initialize MR instance
    #print(dumps(my_mr.as_json(),indent=4))
    validate_me(my_mr)
    my_bundle = bundle_me(my_mr,my_bundle) # as transaction
print(dumps(my_bundle.as_json(),indent=4))
validate_me(my_bundle)
save_me(my_bundle)
post_me(my_bundle)
# Out:
# ***************** row = 0 *******************
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 200</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr></table></div>
# ***************** row = 1 *******************
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 200</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr></table></div>
# ***************** row = 2 *******************
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 200</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr></table></div>
# ***************** row = 3 *******************
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 200</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr></table></div>
# ***************** row = 4 *******************
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 200</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr></table></div>
# ***************** row = 5 *******************
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 200</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr></table></div>
# ***************** row = 6 *******************
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 200</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr></table></div>
# ***************** row = 7 *******************
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 200</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr></table></div>
# {
#     "resourceType": "Bundle",
#     "id": "cdc-c19-groups-20200404070053493066",
#     "type": "transaction",
#     "timestamp": "2020-04-04T07:00:53.208624Z",
#     "entry": [
#         {
#             "fullUrl": "urn:uuid:065d7ece-7642-11ea-be32-a4d18ccf5172",
#             "resource": {
#                 "resourceType": "MeasureReport",
#                 "id": "065d7ece-7642-11ea-be32-a4d18ccf5172",
#                 "status": "complete",
#                 "type": "individual",
#                 "measure": "http://cdcmeasures.example.org/modules/covid19/20200331/numTotBeds",
#                 "subject": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "date": "2020-04-04T07:00:53.208624Z",
#                 "reporter": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "period": {
#                     "start": "2020-03-30",
#                     "end": "2020-03-30"
#                 },
#                 "group": [
#                     {
#                         "code": {
#                             "text": "Hospital Bed/ICU Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numVent",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numVentUse",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 3
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Hospital Ventilator Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numTotBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 125
#                             },
#                             {
#                                 "id": "numbeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 100
#                             },
#                             {
#                                 "id": "numBedsOcc",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 70
#                             },
#                             {
#                                 "id": "numICUBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numICUBedsOcc",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 10
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Patient Impact"
#                         },
#                         "population": [
#                             {
#                                 "id": "numC19HospPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numC19MechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 3
#                             },
#                             {
#                                 "id": "numC19HOPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OverflowPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OFMechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19Died",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "request": {
#                 "method": "POST",
#                 "url": "MeasureReport"
#             }
#         },
#         {
#             "fullUrl": "urn:uuid:06870a64-7642-11ea-be32-a4d18ccf5172",
#             "resource": {
#                 "resourceType": "MeasureReport",
#                 "id": "06870a64-7642-11ea-be32-a4d18ccf5172",
#                 "status": "complete",
#                 "type": "individual",
#                 "measure": "http://cdcmeasures.example.org/modules/covid19/20200331/numTotBeds",
#                 "subject": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "date": "2020-04-04T07:00:53.208624Z",
#                 "reporter": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "period": {
#                     "start": "2020-03-31",
#                     "end": "2020-03-31"
#                 },
#                 "group": [
#                     {
#                         "code": {
#                             "text": "Hospital Bed/ICU Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numVent",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numVentUse",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 3
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Hospital Ventilator Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numTotBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 125
#                             },
#                             {
#                                 "id": "numbeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 100
#                             },
#                             {
#                                 "id": "numBedsOcc",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 72
#                             },
#                             {
#                                 "id": "numICUBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numICUBedsOcc",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 11
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Patient Impact"
#                         },
#                         "population": [
#                             {
#                                 "id": "numC19HospPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 21
#                             },
#                             {
#                                 "id": "numC19MechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 3
#                             },
#                             {
#                                 "id": "numC19HOPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OverflowPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OFMechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19Died",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "request": {
#                 "method": "POST",
#                 "url": "MeasureReport"
#             }
#         },
#         {
#             "fullUrl": "urn:uuid:06b0840c-7642-11ea-be32-a4d18ccf5172",
#             "resource": {
#                 "resourceType": "MeasureReport",
#                 "id": "06b0840c-7642-11ea-be32-a4d18ccf5172",
#                 "status": "complete",
#                 "type": "individual",
#                 "measure": "http://cdcmeasures.example.org/modules/covid19/20200331/numTotBeds",
#                 "subject": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "date": "2020-04-04T07:00:53.208624Z",
#                 "reporter": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "period": {
#                     "start": "2020-04-01",
#                     "end": "2020-04-01"
#                 },
#                 "group": [
#                     {
#                         "code": {
#                             "text": "Hospital Bed/ICU Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numVent",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numVentUse",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 5
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Hospital Ventilator Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numTotBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 125
#                             },
#                             {
#                                 "id": "numbeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 100
#                             },
#                             {
#                                 "id": "numBedsOcc",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 74
#                             },
#                             {
#                                 "id": "numICUBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numICUBedsOcc",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 12
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Patient Impact"
#                         },
#                         "population": [
#                             {
#                                 "id": "numC19HospPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 22
#                             },
#                             {
#                                 "id": "numC19MechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 5
#                             },
#                             {
#                                 "id": "numC19HOPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OverflowPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OFMechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19Died",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "request": {
#                 "method": "POST",
#                 "url": "MeasureReport"
#             }
#         },
#         {
#             "fullUrl": "urn:uuid:06dc071c-7642-11ea-be32-a4d18ccf5172",
#             "resource": {
#                 "resourceType": "MeasureReport",
#                 "id": "06dc071c-7642-11ea-be32-a4d18ccf5172",
#                 "status": "complete",
#                 "type": "individual",
#                 "measure": "http://cdcmeasures.example.org/modules/covid19/20200331/numTotBeds",
#                 "subject": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "date": "2020-04-04T07:00:53.208624Z",
#                 "reporter": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "period": {
#                     "start": "2020-04-02",
#                     "end": "2020-04-02"
#                 },
#                 "group": [
#                     {
#                         "code": {
#                             "text": "Hospital Bed/ICU Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numVent",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numVentUse",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 5
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Hospital Ventilator Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numTotBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 125
#                             },
#                             {
#                                 "id": "numbeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 100
#                             },
#                             {
#                                 "id": "numBedsOcc",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 76
#                             },
#                             {
#                                 "id": "numICUBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numICUBedsOcc",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 13
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Patient Impact"
#                         },
#                         "population": [
#                             {
#                                 "id": "numC19HospPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 23
#                             },
#                             {
#                                 "id": "numC19MechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 5
#                             },
#                             {
#                                 "id": "numC19HOPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OverflowPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OFMechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19Died",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "request": {
#                 "method": "POST",
#                 "url": "MeasureReport"
#             }
#         },
#         {
#             "fullUrl": "urn:uuid:07061d9a-7642-11ea-be32-a4d18ccf5172",
#             "resource": {
#                 "resourceType": "MeasureReport",
#                 "id": "07061d9a-7642-11ea-be32-a4d18ccf5172",
#                 "status": "complete",
#                 "type": "individual",
#                 "measure": "http://cdcmeasures.example.org/modules/covid19/20200331/numTotBeds",
#                 "subject": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "date": "2020-04-04T07:00:53.208624Z",
#                 "reporter": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "period": {
#                     "start": "2020-04-03",
#                     "end": "2020-04-03"
#                 },
#                 "group": [
#                     {
#                         "code": {
#                             "text": "Hospital Bed/ICU Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numVent",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numVentUse",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 7
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Hospital Ventilator Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numTotBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
# ...
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OFMechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19Died",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "request": {
#                 "method": "POST",
#                 "url": "MeasureReport"
#             }
#         },
#         {
#             "fullUrl": "urn:uuid:07866220-7642-11ea-be32-a4d18ccf5172",
#             "resource": {
#                 "resourceType": "MeasureReport",
#                 "id": "07866220-7642-11ea-be32-a4d18ccf5172",
#                 "status": "complete",
#                 "type": "individual",
#                 "measure": "http://cdcmeasures.example.org/modules/covid19/20200331/numTotBeds",
#                 "subject": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "date": "2020-04-04T07:00:53.208624Z",
#                 "reporter": {
#                     "identifier": {
#                         "system": "urn:oid:2.16.840.1.113883.6.277",
#                         "value": "2.16.840.1.113883.6.277.123"
#                     }
#                 },
#                 "period": {
#                     "start": "2020-04-06",
#                     "end": "2020-04-06"
#                 },
#                 "group": [
#                     {
#                         "code": {
#                             "text": "Hospital Bed/ICU Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numVent",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numVentUse",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 9
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Hospital Ventilator Capacity"
#                         },
#                         "population": [
#                             {
#                                 "id": "numTotBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 125
#                             },
#                             {
#                                 "id": "numbeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 100
#                             },
#                             {
#                                 "id": "numBedsOcc",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 84
#                             },
#                             {
#                                 "id": "numICUBeds",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 20
#                             },
#                             {
#                                 "id": "numICUBedsOcc",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 17
#                             }
#                         ]
#                     },
#                     {
#                         "code": {
#                             "text": "Patient Impact"
#                         },
#                         "population": [
#                             {
#                                 "id": "numC19HospPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 27
#                             },
#                             {
#                                 "id": "numC19MechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 9
#                             },
#                             {
#                                 "id": "numC19HOPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OverflowPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19OFMechVentPats",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 0
#                             },
#                             {
#                                 "id": "numC19Died",
#                                 "code": {
#                                     "coding": [
#                                         {
#                                             "system": "http://terminology.hl7.org/CodeSystem/measure-population",
#                                             "code": "initial-population"
#                                         }
#                                     ]
#                                 },
#                                 "count": 1
#                             }
#                         ]
#                     }
#                 ]
#             },
#             "request": {
#                 "method": "POST",
#                 "url": "MeasureReport"
#             }
#         }
#     ]
# }
# validating to http://test.fhir.org/r4...
# <h1>Validation output</h1><h3>Status Code = 200</h3><div><p><b>Operation Outcome for :Validate resource </b></p><table class="grid"><tr><td><b>Severity</b></td><td><b>Location</b></td><td><b>Details</b></td><td><b>Diagnostics</b></td><td><b>Type</b></td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>warning</td><td/><td>A resource should have narrative for robust management () text.`div`.exists()</td><td/><td>invariant</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr><tr><td>information</td><td/><td>A Reference without an actual reference should have a display</td><td/><td>structure</td></tr></table></div>
# ...........saving to file............
# posting to http://test.fhir.org/r4 as transaction bundle ...
# <h1>Post Response</h1><h3>Status Code = 200</h3><br /><pre>Response Headers: {
#     "Connection": "close",
#     "Content-Type": "application/fhir+json",
#     "Content-Length": "28871",
#     "Cache-control": "public, max-age=600",
#     "Date": "Sat, 04 Apr 2020 07:00:58 GMT",
#     "ETag": "W/\"1\"",
#     "Pragma": "no-cache",
#     "X-Request-Id": "152-180934",
#     "Access-Control-Allow-Origin": "*",
#     "Access-Control-Expose-Headers": "Content-Location, Location",
#     "Access-Control-Allow-Methods": "GET, POST, PUT, PATCH, DELETE",
#     "X-GDPR-Disclosure": "All access to this server is logged as AuditEvent Resources, and these store your ip address (and logged in user, if one exists). Also, your IP address is logged with Google Analytics for building geomaps of server usage. Your continued use of the API constitutes agreement to these terms. See [link] for erasure requests",
#     "Last-Modified": "Sat, 04 Apr 2020 07:00:58 GMT",
#     "Server": "Health Intersections FHIR Server",
#     "Location": "http://test.fhir.org/r4/MeasureReport/48/_history/1"
# }</pre>===============================================<br /><br /><br />

# %% [markdown]
# ### Convert back to CSV
#
# - create new Dataframe based on the old one ( this is cheating )
# - For each bundle add row to Dataframe
# - save as CSV

# %%
new_df = df.iloc[0:0,:].copy()
for i, entry in enumerate(my_bundle.entry):
    new_row = {}
    mr = entry.resource
    new_row['collectiondate']= mr.period.start.as_json()
    for group in mr.group:
        for pop in group.population:
            new_row[pop.id]= pop.count            
    new_df = new_df.append(new_row, ignore_index=True)

new_df['collectiondate'] = to_datetime(new_df.collectiondate) # convert date to date-time
new_df['collectiondate'] = new_df['collectiondate'].dt.strftime('%m/%d/%Y')
new_df
# Out:
#   collectiondate  numTotBeds  numbeds  numBedsOcc  numICUBeds  numICUBedsOcc  \
# 0     03/30/2020         125      100          70          20             10
# 1     03/31/2020         125      100          72          20             11
# 2     04/01/2020         125      100          74          20             12
# 3     04/02/2020         125      100          76          20             13
# 4     04/03/2020         125      100          78          20             14
# 5     04/04/2020         125      100          80          20             15
# 6     04/05/2020         125      100          82          20             16
# 7     04/06/2020         125      100          84          20             17
#
#    numVent  numVentUse  numC19HospPats  numC19MechVentPats  numC19HOPats  \
# 0       20           3              20                   3             0
# 1       20           3              21                   3             0
# 2       20           5              22                   5             0
# 3       20           5              23                   5             0
# 4       20           7              24                   7             0
# 5       20           7              25                   7             0
# 6       20           9              26                   9             0
# 7       20           9              27                   9             0
#
#    numC19OverflowPats  numC19OFMechVentPats  numC19Died
# 0                   0                     0           0
# 1                   0                     0           0
# 2                   0                     0           0
# 3                   0                     0           0
# 4                   0                     0           1
# 5                   0                     0           0
# 6                   0                     0           0
# 7                   0                     0           1

# %%
path = Path.cwd() / out_path / f'{my_bundle.resource_type}-{my_bundle.id.lower()}.csv'
print(f'....saving {my_bundle.resource_type}-{my_bundle.id.lower()}.csv to file ....')
new_df.to_csv(path, index=False)
# Out:
# ....saving Bundle-cdc-c19-groups-20200404064021623933.csv to file ....
