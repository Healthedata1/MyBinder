# %% [markdown]
# ## Creation of Python FHIR Models using the SMART Fhir Parser
#
# You can skip down to [step 3](#3_cell) below to see how to use these new and improved models for R4.
#
# ### 1. Clone the [FHIR Model Generator repository](https://github.com/hsolbrig/fhir_model_generator)
#
#
#     $ git clone https://github.com/hsolbrig/fhir_model_generator.git
#
# <br/>
#
# * If you are not familiar with Git and using the command line, check out this great tutorial by Corey Schafer:
#
#   [![github_tut](github-basics.png)](https://www.youtube.com/embed/HVsySz-h9r4 "Git Tutorial for Beginners")

# %%
# %%bash
# git clone https://github.com/hsolbrig/fhir_model_generator.git

# %% [markdown]
# ###  2. Run the Bash script "generate_models.sh"
#
# ~~~
#       $ cd fhir_model_generator
#       $ bash generate_models.sh [options]
#
# where options are: [-h] [-f] [-c] [-lo] [-po] [-u FHIRURL] [-td TEMPLATEDIR]
#                   [-o OUTPUTDIR] [-cd CACHEDIR] [--nosort]
#                   settings
#
# positional arguments:
#   settings              Location of the settings file. Default is settings.py
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -f, --force           Force download of the spec
#   -c, --cached          Force use of the cached spec (incompatible with "-f")
#   -lo, --loadonly       Load the spec but do not parse or write resources
#   -po, --parseonly      Load and parse but do not write resources
#   -u FHIRURL, --fhirurl FHIRURL
#                         FHIR Specification URL (overrides
#                         settings.specifications_url)
#   -td TEMPLATEDIR, --templatedir TEMPLATEDIR
#                         Templates base directory (overrides settings.tpl_base)
#   -o OUTPUTDIR, --outputdir OUTPUTDIR
#                         Directory for generated class models. (overrides
#                         settings.tpl_resource_target)
#   -cd CACHEDIR, --cachedir CACHEDIR
#                         Cache directory (default: downloads)
#   --nosort              If set, do not sort resource properties alphabetically
# ~~~
#
# for this notebook we are going to use the -f and option as shown below:
#
# ~~~
#       $ cd fhir_model_generator
#       $ bash generate_models.sh -f
# ~~~
#
#     - The first time you need the "-f" option
#     - the default OUTPUTDIR will be "pyFHIR_models/fhir_model_generator/model"
#
# - **Note** The shell generates the models, but does not run the test cases yet.
#
# - You will need to run this script in a Python 3.6+ environment. The script will invoke [*pipenv*](https://www.google.com/url?sa=t&rct=j&q=&esrc=s&source=web&cd=7&ved=2ahUKEwiknaLOmL7nAhUW4nMBHS3RCDoQFjAGegQIBxAB&url=https%3A%2F%2Frealpython.com%2Fpipenv-guide%2F&usg=AOvVaw1MjJYeu3Y6E5JjOCxMcE08).  Which you will need to install in your Python Environment.
#
# - If you don't know how to set up your python environment check out these great tutorials by Corey Schafer:
#
#   [![python_install](py-install.png)](https://www.youtube.com/embed/YYXdXT2l-Gg "Python Tutorial for Beginners 1: Install and Setup for Mac and Windows")
#
#   [![virtenv](virtenv.png)](https://www.youtube.com/embed/N5vscPTWKOk "Python Tutorial: virtualenv and why you should use virtual environments")
#
# - If you don't know how to run a bash script check out this great tutorial by *Quids Up* to get you the bare bones basics:
#
#   [![bash_basics](bash-basics.png)](https://www.youtube.com/embed/dD5RgCf1hrI "Bash Tutorial 1: Hello World")
#
# - If you are on Windows, I recommend using the bash shell supplied by GitHub. Git Bash comes included as part of the Git For Windows package. Download and install Git For Windows like other Windows applications  It is available if you right click on a file folder.
#
#   ![get-gitbash](get-gitbash.png)

# %%
cd ~/pyFHIR_models

# %%
# %%bash
# echo "this will install the environment to run the FHIR-Parser"
# cd fhir_model_generator
# echo "the first step is to download the FHIR build resources..."
# echo "this will take a minute or so....."
# bash generate_models.sh
# echo "need to add a __init__.py so we can use it as a module"
# cd model
# touch __init__.py
# Out:
# this will install the environment to run the FHIR-Parser
# the first step is to download the FHIR build resources...
# this will take a minute or so.....
# Installing dependencies from Pipfile.lock (01d5bf)…
# ~/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/fhir-parser-resources ~/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator
# ~/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator
# ~/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/fhir-parser-resources ~/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator
# ~/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator
# need to add a __init__.py so we can use it as a module
# bash: line 2: cd: fhir_model_generator: No such file or directory
# Courtesy Notice: Pipenv found itself running within a virtual environment, so it will automatically use that environment, instead of creating its own for any project. You can set PIPENV_IGNORE_VIRTUALENVS=1 to force pipenv to ignore that environment and create its own instead. You can set PIPENV_VERBOSITY=-1 to suppress this warning.
# Warning: There was an unexpected error while activating your virtualenv. Continuing anyway...
#   INFO     | Loading settings from fhir-parser-resources/settings.py
#   INFO     | Resource properties are not sorted
#   INFO     | Specification: http://hl7.org/fhir/R4
#   INFO     | Template directory: fhir-parser-resources
#   INFO     | Output directory: model
#   INFO     | Unit test directory: tests/model
#   INFO     | Cache directory: downloads
#   INFO     | Using cached resources, supply "-f" to re-download
#   INFO     | Reading valuesets.json
#   WARNING  | CodeSystem with no concepts: http://snomed.info/sct
#   WARNING  | CodeSystem with no concepts: http://hl7.org/fhir/CodeSystem/summary
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/object-role" because at least one concept code starts with a number
#   DEBUG    | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/insurance-plan-type" whose content is fragment
#   INFO     | Will not generate enum for CodeSystem "http://hl7.org/fhir/FHIR-version" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://hl7.org/fhir/ex-oralprostho" because at least one concept code starts with a number
#   DEBUG    | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/service-type" whose content is example
#   INFO     | Will not generate enum for CodeSystem "http://hl7.org/fhir/spdx-license" because it has > 200 (346) concepts
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/security-source-type" because at least one concept code starts with a number
#   DEBUG    | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/service-category" whose content is example
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/ex-tooth" because at least one concept code starts with a number
#   DEBUG    | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/appointment-cancellation-reason" whose content is example
#   INFO     | Will not generate enum for CodeSystem "urn:oid:1.2.36.1.2001.1001.101.104.16592" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://hl7.org/fhir/ex-fdi" because at least one concept code starts with a number
#   DEBUG    | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/program" whose content is example
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/chargeitem-billingcodes" because at least one concept code starts with a number
#   WARNING  | CodeSystem with no concepts: http://hl7.org/fhir/message-events
#   INFO     | Will not generate enum for CodeSystem "http://hl7.org/fhir/sid/ex-icd-10-procedures" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/ex-serviceplace" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/audit-entity-type" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/ex-revenue-center" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/ex-diagnosisrelatedgroup" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/observation-statistics" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/dicom-audit-lifecycle" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "urn:iso-astm:E1762-95:2013" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/ex-USCLS" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://hl7.org/fhir/audit-event-outcome" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://hl7.org/fhir/fm-conditions" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://dicom.nema.org/resources/ontology/DCM" because it has > 200 (3156) concepts
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/chromosome-human" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://hl7.org/fhir/network-type" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/ex-providerqualification" because at least one concept code starts with a number
#   INFO     | Will not generate enum for CodeSystem "http://terminology.hl7.org/CodeSystem/ex-benefitcategory" because at least one concept code starts with a number
#   INFO     | Found 672 ValueSets and 492 CodeSystems
#   DEBUG    | Created class "bool", module fhirabstractbase
#   DEBUG    | Created class "str", module fhirabstractbase
#   DEBUG    | Already have profile "str", discarding
#   DEBUG    | Already have profile "str", discarding
#   DEBUG    | Already have profile "str", discarding
#   DEBUG    | Created class "float", module fhirabstractbase
#   DEBUG    | Created class "int", module fhirabstractbase
#   DEBUG    | Already have profile "int", discarding
#   DEBUG    | Already have profile "int", discarding
#   DEBUG    | Already have profile "str", discarding
#   DEBUG    | Already have profile "str", discarding
#   DEBUG    | Already have profile "str", discarding
#   DEBUG    | Created class "FHIRAbstractBase", module fhirabstractbase
#   DEBUG    | Created class "FHIRAbstractResource", module fhirabstractresource
#   DEBUG    | Created class "FHIRReference", module fhirreference
#   DEBUG    | Created class "FHIRDate", module fhirdate
#   DEBUG    | Already have profile "FHIRDate", discarding
#   DEBUG    | Already have profile "FHIRDate", discarding
#   DEBUG    | Already have profile "FHIRDate", discarding
#   DEBUG    | Created class "FHIRSearch", module fhirsearch
#   INFO     | Reading profiles-types.json
#   INFO     | Reading profiles-resources.json
#   DEBUG    | Not handling resource of type CapabilityStatement
#   DEBUG    | Not handling resource of type CapabilityStatement
#   DEBUG    | Not handling resource of type CompartmentDefinition
#   DEBUG    | Not handling resource of type CompartmentDefinition
#   DEBUG    | Not handling resource of type CompartmentDefinition
#   DEBUG    | Not handling resource of type CompartmentDefinition
#   DEBUG    | Not handling resource of type CompartmentDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   DEBUG    | Not handling resource of type OperationDefinition
#   INFO     | Parsing profile "Element"
#   DEBUG    | Created class "Element", module element
#   INFO     | Parsing profile "BackboneElement"
#   DEBUG    | Created class "BackboneElement", module backboneelement
#   INFO     | Parsing profile "base64Binary"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "boolean"
#   DEBUG    | Already have profile "bool", discarding
#   INFO     | Parsing profile "canonical"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "code"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "date"
#   DEBUG    | Already have profile "FHIRDate", discarding
#   INFO     | Parsing profile "dateTime"
#   DEBUG    | Already have profile "FHIRDate", discarding
#   INFO     | Parsing profile "decimal"
#   DEBUG    | Already have profile "float", discarding
#   INFO     | Parsing profile "id"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "instant"
#   DEBUG    | Already have profile "FHIRDate", discarding
#   INFO     | Parsing profile "integer"
#   DEBUG    | Already have profile "int", discarding
#   INFO     | Parsing profile "markdown"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "oid"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "positiveInt"
#   DEBUG    | Already have profile "int", discarding
#   INFO     | Parsing profile "string"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "time"
#   DEBUG    | Already have profile "FHIRDate", discarding
#   INFO     | Parsing profile "unsignedInt"
#   DEBUG    | Already have profile "int", discarding
#   INFO     | Parsing profile "uri"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "url"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "uuid"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "xhtml"
#   DEBUG    | Already have profile "str", discarding
#   INFO     | Parsing profile "Address"
#   DEBUG    | Created class "Address", module address
#   INFO     | Parsing profile "Age"
#   DEBUG    | Created class "Age", module age
#   INFO     | Parsing profile "Annotation"
#   DEBUG    | Created class "Annotation", module annotation
#   INFO     | Parsing profile "Attachment"
#   DEBUG    | Created class "Attachment", module attachment
#   INFO     | Parsing profile "CodeableConcept"
#   DEBUG    | Created class "CodeableConcept", module codeableconcept
#   INFO     | Parsing profile "Coding"
#   DEBUG    | Created class "Coding", module coding
#   INFO     | Parsing profile "ContactDetail"
#   DEBUG    | Created class "ContactDetail", module contactdetail
#   INFO     | Parsing profile "ContactPoint"
#   DEBUG    | Created class "ContactPoint", module contactpoint
#   INFO     | Parsing profile "Contributor"
#   DEBUG    | Created class "Contributor", module contributor
#   INFO     | Parsing profile "Count"
#   DEBUG    | Created class "Count", module count
#   INFO     | Parsing profile "DataRequirement"
#   WARNING  | Ignoring ValueSet with more than 1 includes (3: [{'system': 'http://hl7.org/fhir/data-types'}, {'system': 'http://hl7.org/fhir/resource-types'}, {'system': 'http://hl7.org/fhir/abstract-types'}])
#   DEBUG    | Created class "DataRequirement", module datarequirement
#   DEBUG    | Created class "DataRequirementCodeFilter", module datarequirement
#   DEBUG    | Created class "DataRequirementDateFilter", module datarequirement
#   DEBUG    | Created class "DataRequirementSort", module datarequirement
#   INFO     | Parsing profile "Distance"
#   DEBUG    | Created class "Distance", module distance
#   INFO     | Parsing profile "Dosage"
#   DEBUG    | Created class "Dosage", module dosage
#   DEBUG    | Created class "DosageDoseAndRate", module dosage
#   INFO     | Parsing profile "Duration"
#   DEBUG    | Created class "Duration", module duration
#   INFO     | Parsing profile "ElementDefinition"
#   DEBUG    | Created class "ElementDefinition", module elementdefinition
#   DEBUG    | Created class "ElementDefinitionSlicing", module elementdefinition
#   DEBUG    | Created class "ElementDefinitionSlicingDiscriminator", module elementdefinition
#   DEBUG    | Created class "ElementDefinitionBase", module elementdefinition
#   DEBUG    | Created class "ElementDefinitionType", module elementdefinition
#   DEBUG    | Created class "ElementDefinitionExample", module elementdefinition
#   DEBUG    | Created class "ElementDefinitionConstraint", module elementdefinition
#   DEBUG    | Created class "ElementDefinitionBinding", module elementdefinition
#   DEBUG    | Created class "ElementDefinitionMapping", module elementdefinition
#   INFO     | Parsing profile "Expression"
#   DEBUG    | Created class "Expression", module expression
#   INFO     | Parsing profile "Extension"
#   DEBUG    | Created class "Extension", module extension
#   INFO     | Parsing profile "HumanName"
#   DEBUG    | Created class "HumanName", module humanname
#   INFO     | Parsing profile "Identifier"
#   DEBUG    | Created class "Identifier", module identifier
#   INFO     | Parsing profile "MarketingStatus"
#   DEBUG    | Created class "MarketingStatus", module marketingstatus
#   INFO     | Parsing profile "Meta"
#   DEBUG    | Created class "Meta", module meta
#   INFO     | Parsing profile "Money"
#   DEBUG    | Created class "Money", module money
#   INFO     | Parsing profile "Narrative"
#   DEBUG    | Created class "Narrative", module narrative
#   INFO     | Parsing profile "ParameterDefinition"
#   WARNING  | Ignoring ValueSet with more than 1 includes (3: [{'system': 'http://hl7.org/fhir/data-types'}, {'system': 'http://hl7.org/fhir/resource-types'}, {'system': 'http://hl7.org/fhir/abstract-types'}])
#   DEBUG    | Created class "ParameterDefinition", module parameterdefinition
#   INFO     | Parsing profile "Period"
#   DEBUG    | Created class "Period", module period
#   INFO     | Parsing profile "Population"
#   DEBUG    | Created class "Population", module population
#   INFO     | Parsing profile "ProdCharacteristic"
#   DEBUG    | Created class "ProdCharacteristic", module prodcharacteristic
#   INFO     | Parsing profile "ProductShelfLife"
#   DEBUG    | Created class "ProductShelfLife", module productshelflife
#   INFO     | Parsing profile "Quantity"
#   DEBUG    | Created class "Quantity", module quantity
#   INFO     | Parsing profile "Range"
#   DEBUG    | Created class "Range", module range
#   INFO     | Parsing profile "Ratio"
#   DEBUG    | Created class "Ratio", module ratio
#   INFO     | Parsing profile "Reference"
#   DEBUG    | Created class "Reference", module reference
#   INFO     | Parsing profile "RelatedArtifact"
#   DEBUG    | Created class "RelatedArtifact", module relatedartifact
#   INFO     | Parsing profile "SampledData"
#   DEBUG    | Created class "SampledData", module sampleddata
#   INFO     | Parsing profile "Signature"
#   DEBUG    | Created class "Signature", module signature
#   INFO     | Parsing profile "SubstanceAmount"
#   DEBUG    | Created class "SubstanceAmount", module substanceamount
#   DEBUG    | Created class "SubstanceAmountReferenceRange", module substanceamount
#   INFO     | Parsing profile "Timing"
#   WARNING  | Ignoring ValueSet with more than 1 includes (2: [{'system': 'http://hl7.org/fhir/event-timing'}, {'system': 'http://terminology.hl7.org/CodeSystem/v3-TimingEvent', 'concept': [{'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs [offset] before the hour of sleep (or trying to)'}], 'code': 'HS'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs [offset] after waking'}], 'code': 'WAKE'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs at a meal (from the Latin cibus)'}], 'code': 'C'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs at breakfast (from the Latin cibus matutinus)'}], 'code': 'CM'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs at lunch (from the Latin cibus diurnus)'}], 'code': 'CD'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs at dinner (from the Latin ante cibus vespertinus)'}], 'code': 'CV'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs [offset] before a meal (from the Latin ante cibus)'}], 'code': 'AC'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs [offset] before breakfast (from the Latin ante cibus matutinus)'}], 'code': 'ACM'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs [offset] before lunch (from the Latin ante cibus diurnus)'}], 'code': 'ACD'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs [offset] before dinner (from the Latin ante cibus vespertinus)'}], 'code': 'ACV'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs [offset] after a meal (from the Latin post cibus)'}], 'code': 'PC'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs [offset] after breakfast (from the Latin post cibus matutinus)'}], 'code': 'PCM'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs [offset] after lunch (from the Latin post cibus diurnus)'}], 'code': 'PCD'}, {'extension': [{'url': 'http://hl7.org/fhir/StructureDefinition/valueset-concept-definition', 'valueString': 'event occurs [offset] after dinner (from the Latin post cibus vespertinus)'}], 'code': 'PCV'}]}])
#   DEBUG    | Created class "Timing", module timing
#   DEBUG    | Created class "TimingRepeat", module timing
#   INFO     | Parsing profile "TriggerDefinition"
#   DEBUG    | Created class "TriggerDefinition", module triggerdefinition
#   INFO     | Parsing profile "UsageContext"
#   DEBUG    | Created class "UsageContext", module usagecontext
#   INFO     | Parsing profile "MoneyQuantity"
#   INFO     | Parsing profile "SimpleQuantity"
#   INFO     | Skipping "http://hl7.org/fhir/StructureDefinition/SimpleQuantity"
#   INFO     | Parsing profile "Resource"
#   DEBUG    | Created class "Resource", module resource
#   INFO     | Parsing profile "Account"
#   DEBUG    | Created class "Account", module account
#   DEBUG    | Created class "AccountCoverage", module account
#   DEBUG    | Created class "AccountGuarantor", module account
#   INFO     | Parsing profile "ActivityDefinition"
#   DEBUG    | Created class "ActivityDefinition", module activitydefinition
#   DEBUG    | Created class "ActivityDefinitionParticipant", module activitydefinition
#   DEBUG    | Created class "ActivityDefinitionDynamicValue", module activitydefinition
#   INFO     | Parsing profile "AdverseEvent"
#   DEBUG    | Created class "AdverseEvent", module adverseevent
#   DEBUG    | Created class "AdverseEventSuspectEntity", module adverseevent
#   DEBUG    | Created class "AdverseEventSuspectEntityCausality", module adverseevent
#   INFO     | Parsing profile "AllergyIntolerance"
#   DEBUG    | Created class "AllergyIntolerance", module allergyintolerance
#   DEBUG    | Created class "AllergyIntoleranceReaction", module allergyintolerance
#   INFO     | Parsing profile "Appointment"
#   DEBUG    | Created class "Appointment", module appointment
#   DEBUG    | Created class "AppointmentParticipant", module appointment
#   INFO     | Parsing profile "AppointmentResponse"
#   DEBUG    | Created class "AppointmentResponse", module appointmentresponse
#   INFO     | Parsing profile "AuditEvent"
#   DEBUG    | Created class "AuditEvent", module auditevent
#   DEBUG    | Created class "AuditEventAgent", module auditevent
#   DEBUG    | Created class "AuditEventAgentNetwork", module auditevent
#   DEBUG    | Created class "AuditEventSource", module auditevent
#   DEBUG    | Created class "AuditEventEntity", module auditevent
#   DEBUG    | Created class "AuditEventEntityDetail", module auditevent
#   INFO     | Parsing profile "Basic"
#   DEBUG    | Created class "Basic", module basic
#   INFO     | Parsing profile "Binary"
#   DEBUG    | Created class "Binary", module binary
#   INFO     | Parsing profile "BiologicallyDerivedProduct"
#   DEBUG    | Created class "BiologicallyDerivedProduct", module biologicallyderivedproduct
#   DEBUG    | Created class "BiologicallyDerivedProductCollection", module biologicallyderivedproduct
#   DEBUG    | Created class "BiologicallyDerivedProductProcessing", module biologicallyderivedproduct
#   DEBUG    | Created class "BiologicallyDerivedProductManipulation", module biologicallyderivedproduct
#   DEBUG    | Created class "BiologicallyDerivedProductStorage", module biologicallyderivedproduct
#   INFO     | Parsing profile "BodyStructure"
#   DEBUG    | Created class "BodyStructure", module bodystructure
#   INFO     | Parsing profile "Bundle"
#   DEBUG    | Created class "Bundle", module bundle
#   DEBUG    | Created class "BundleLink", module bundle
#   DEBUG    | Created class "BundleEntry", module bundle
#   DEBUG    | Created class "BundleEntrySearch", module bundle
#   DEBUG    | Created class "BundleEntryRequest", module bundle
#   DEBUG    | Created class "BundleEntryResponse", module bundle
#   INFO     | Parsing profile "CapabilityStatement"
#   DEBUG    | Created class "CapabilityStatement", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementSoftware", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementImplementation", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementRest", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementRestSecurity", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementRestResource", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementRestResourceInteraction", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementRestResourceSearchParam", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementRestResourceOperation", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementRestInteraction", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementMessaging", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementMessagingEndpoint", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementMessagingSupportedMessage", module capabilitystatement
#   DEBUG    | Created class "CapabilityStatementDocument", module capabilitystatement
#   INFO     | Parsing profile "CarePlan"
#   DEBUG    | Created class "CarePlan", module careplan
#   DEBUG    | Created class "CarePlanActivity", module careplan
#   DEBUG    | Created class "CarePlanActivityDetail", module careplan
#   INFO     | Parsing profile "CareTeam"
#   DEBUG    | Created class "CareTeam", module careteam
#   DEBUG    | Created class "CareTeamParticipant", module careteam
#   INFO     | Parsing profile "CatalogEntry"
#   DEBUG    | Created class "CatalogEntry", module catalogentry
#   DEBUG    | Created class "CatalogEntryRelatedEntry", module catalogentry
#   INFO     | Parsing profile "ChargeItem"
#   DEBUG    | Created class "ChargeItem", module chargeitem
#   DEBUG    | Created class "ChargeItemPerformer", module chargeitem
#   INFO     | Parsing profile "ChargeItemDefinition"
#   DEBUG    | Created class "ChargeItemDefinition", module chargeitemdefinition
#   DEBUG    | Created class "ChargeItemDefinitionApplicability", module chargeitemdefinition
#   DEBUG    | Created class "ChargeItemDefinitionPropertyGroup", module chargeitemdefinition
#   DEBUG    | Created class "ChargeItemDefinitionPropertyGroupPriceComponent", module chargeitemdefinition
#   INFO     | Parsing profile "Claim"
#   DEBUG    | Created class "Claim", module claim
#   DEBUG    | Created class "ClaimRelated", module claim
#   DEBUG    | Created class "ClaimPayee", module claim
#   DEBUG    | Created class "ClaimCareTeam", module claim
#   DEBUG    | Created class "ClaimSupportingInfo", module claim
#   DEBUG    | Created class "ClaimDiagnosis", module claim
#   DEBUG    | Created class "ClaimProcedure", module claim
#   DEBUG    | Created class "ClaimInsurance", module claim
#   DEBUG    | Created class "ClaimAccident", module claim
#   DEBUG    | Created class "ClaimItem", module claim
#   DEBUG    | Created class "ClaimItemDetail", module claim
#   DEBUG    | Created class "ClaimItemDetailSubDetail", module claim
#   INFO     | Parsing profile "ClaimResponse"
#   DEBUG    | Created class "ClaimResponse", module claimresponse
#   DEBUG    | Created class "ClaimResponseItem", module claimresponse
#   DEBUG    | Created class "ClaimResponseItemAdjudication", module claimresponse
#   DEBUG    | Created class "ClaimResponseItemDetail", module claimresponse
#   DEBUG    | Created class "ClaimResponseItemDetailSubDetail", module claimresponse
#   DEBUG    | Created class "ClaimResponseAddItem", module claimresponse
#   DEBUG    | Created class "ClaimResponseAddItemDetail", module claimresponse
#   DEBUG    | Created class "ClaimResponseAddItemDetailSubDetail", module claimresponse
#   DEBUG    | Created class "ClaimResponseTotal", module claimresponse
#   DEBUG    | Created class "ClaimResponsePayment", module claimresponse
#   DEBUG    | Created class "ClaimResponseProcessNote", module claimresponse
#   DEBUG    | Created class "ClaimResponseInsurance", module claimresponse
#   DEBUG    | Created class "ClaimResponseError", module claimresponse
#   INFO     | Parsing profile "ClinicalImpression"
#   DEBUG    | Created class "ClinicalImpression", module clinicalimpression
#   DEBUG    | Created class "ClinicalImpressionInvestigation", module clinicalimpression
#   DEBUG    | Created class "ClinicalImpressionFinding", module clinicalimpression
#   INFO     | Parsing profile "CodeSystem"
#   DEBUG    | Created class "CodeSystem", module codesystem
#   DEBUG    | Created class "CodeSystemFilter", module codesystem
#   DEBUG    | Created class "CodeSystemProperty", module codesystem
#   DEBUG    | Created class "CodeSystemConcept", module codesystem
#   DEBUG    | Created class "CodeSystemConceptDesignation", module codesystem
#   DEBUG    | Created class "CodeSystemConceptProperty", module codesystem
#   INFO     | Parsing profile "Communication"
#   DEBUG    | Created class "Communication", module communication
#   DEBUG    | Created class "CommunicationPayload", module communication
#   INFO     | Parsing profile "CommunicationRequest"
#   DEBUG    | Created class "CommunicationRequest", module communicationrequest
#   DEBUG    | Created class "CommunicationRequestPayload", module communicationrequest
#   INFO     | Parsing profile "CompartmentDefinition"
#   DEBUG    | Created class "CompartmentDefinition", module compartmentdefinition
#   DEBUG    | Created class "CompartmentDefinitionResource", module compartmentdefinition
#   INFO     | Parsing profile "Composition"
#   DEBUG    | Ignoring foreign ValueSet "http://terminology.hl7.org/ValueSet/v3-ConfidentialityClassification|2014-03-26"
#   DEBUG    | Created class "Composition", module composition
#   DEBUG    | Created class "CompositionAttester", module composition
#   DEBUG    | Created class "CompositionRelatesTo", module composition
#   DEBUG    | Created class "CompositionEvent", module composition
#   DEBUG    | Created class "CompositionSection", module composition
#   INFO     | Parsing profile "ConceptMap"
#   DEBUG    | Created class "ConceptMap", module conceptmap
#   DEBUG    | Created class "ConceptMapGroup", module conceptmap
#   DEBUG    | Created class "ConceptMapGroupElement", module conceptmap
#   DEBUG    | Created class "ConceptMapGroupElementTarget", module conceptmap
#   DEBUG    | Created class "ConceptMapGroupElementTargetDependsOn", module conceptmap
#   DEBUG    | Created class "ConceptMapGroupUnmapped", module conceptmap
#   INFO     | Parsing profile "Condition"
#   DEBUG    | Created class "Condition", module condition
#   DEBUG    | Created class "ConditionStage", module condition
#   DEBUG    | Created class "ConditionEvidence", module condition
#   INFO     | Parsing profile "Consent"
#   DEBUG    | Created class "Consent", module consent
#   DEBUG    | Created class "ConsentPolicy", module consent
#   DEBUG    | Created class "ConsentVerification", module consent
#   DEBUG    | Created class "ConsentProvision", module consent
#   DEBUG    | Created class "ConsentProvisionActor", module consent
#   DEBUG    | Created class "ConsentProvisionData", module consent
#   INFO     | Parsing profile "Contract"
#   DEBUG    | Created class "Contract", module contract
#   DEBUG    | Created class "ContractContentDefinition", module contract
#   DEBUG    | Created class "ContractTerm", module contract
#   DEBUG    | Created class "ContractTermSecurityLabel", module contract
#   DEBUG    | Created class "ContractTermOffer", module contract
#   DEBUG    | Created class "ContractTermOfferParty", module contract
#   DEBUG    | Created class "ContractTermOfferAnswer", module contract
#   DEBUG    | Created class "ContractTermAsset", module contract
#   DEBUG    | Created class "ContractTermAssetContext", module contract
#   DEBUG    | Created class "ContractTermAssetValuedItem", module contract
#   DEBUG    | Created class "ContractTermAction", module contract
#   DEBUG    | Created class "ContractTermActionSubject", module contract
#   DEBUG    | Created class "ContractSigner", module contract
#   DEBUG    | Created class "ContractFriendly", module contract
#   DEBUG    | Created class "ContractLegal", module contract
#   DEBUG    | Created class "ContractRule", module contract
#   INFO     | Parsing profile "Coverage"
#   DEBUG    | Created class "Coverage", module coverage
#   DEBUG    | Created class "CoverageClass", module coverage
#   DEBUG    | Created class "CoverageCostToBeneficiary", module coverage
#   DEBUG    | Created class "CoverageCostToBeneficiaryException", module coverage
#   INFO     | Parsing profile "CoverageEligibilityRequest"
#   DEBUG    | Created class "CoverageEligibilityRequest", module coverageeligibilityrequest
#   DEBUG    | Created class "CoverageEligibilityRequestSupportingInfo", module coverageeligibilityrequest
#   DEBUG    | Created class "CoverageEligibilityRequestInsurance", module coverageeligibilityrequest
#   DEBUG    | Created class "CoverageEligibilityRequestItem", module coverageeligibilityrequest
#   DEBUG    | Created class "CoverageEligibilityRequestItemDiagnosis", module coverageeligibilityrequest
#   INFO     | Parsing profile "CoverageEligibilityResponse"
#   DEBUG    | Created class "CoverageEligibilityResponse", module coverageeligibilityresponse
#   DEBUG    | Created class "CoverageEligibilityResponseInsurance", module coverageeligibilityresponse
#   DEBUG    | Created class "CoverageEligibilityResponseInsuranceItem", module coverageeligibilityresponse
#   DEBUG    | Created class "CoverageEligibilityResponseInsuranceItemBenefit", module coverageeligibilityresponse
#   DEBUG    | Created class "CoverageEligibilityResponseError", module coverageeligibilityresponse
#   INFO     | Parsing profile "DetectedIssue"
#   DEBUG    | Created class "DetectedIssue", module detectedissue
#   DEBUG    | Created class "DetectedIssueEvidence", module detectedissue
#   DEBUG    | Created class "DetectedIssueMitigation", module detectedissue
#   INFO     | Parsing profile "Device"
#   DEBUG    | Created class "Device", module device
#   DEBUG    | Created class "DeviceUdiCarrier", module device
#   DEBUG    | Created class "DeviceDeviceName", module device
#   DEBUG    | Created class "DeviceSpecialization", module device
#   DEBUG    | Created class "DeviceVersion", module device
#   DEBUG    | Created class "DeviceProperty", module device
#   INFO     | Parsing profile "DeviceDefinition"
#   DEBUG    | Created class "DeviceDefinition", module devicedefinition
#   DEBUG    | Created class "DeviceDefinitionUdiDeviceIdentifier", module devicedefinition
#   DEBUG    | Created class "DeviceDefinitionDeviceName", module devicedefinition
#   DEBUG    | Created class "DeviceDefinitionSpecialization", module devicedefinition
#   DEBUG    | Created class "DeviceDefinitionCapability", module devicedefinition
#   DEBUG    | Created class "DeviceDefinitionProperty", module devicedefinition
#   DEBUG    | Created class "DeviceDefinitionMaterial", module devicedefinition
#   INFO     | Parsing profile "DeviceMetric"
#   DEBUG    | Created class "DeviceMetric", module devicemetric
#   DEBUG    | Created class "DeviceMetricCalibration", module devicemetric
#   INFO     | Parsing profile "DeviceRequest"
#   DEBUG    | Created class "DeviceRequest", module devicerequest
#   DEBUG    | Created class "DeviceRequestParameter", module devicerequest
#   INFO     | Parsing profile "DeviceUseStatement"
#   DEBUG    | Created class "DeviceUseStatement", module deviceusestatement
#   INFO     | Parsing profile "DiagnosticReport"
#   DEBUG    | Created class "DiagnosticReport", module diagnosticreport
#   DEBUG    | Created class "DiagnosticReportMedia", module diagnosticreport
#   INFO     | Parsing profile "DocumentManifest"
#   DEBUG    | Created class "DocumentManifest", module documentmanifest
#   DEBUG    | Created class "DocumentManifestRelated", module documentmanifest
#   INFO     | Parsing profile "DocumentReference"
#   DEBUG    | Created class "DocumentReference", module documentreference
#   DEBUG    | Created class "DocumentReferenceRelatesTo", module documentreference
#   DEBUG    | Created class "DocumentReferenceContent", module documentreference
#   DEBUG    | Created class "DocumentReferenceContext", module documentreference
#   INFO     | Parsing profile "DomainResource"
#   DEBUG    | Created class "DomainResource", module domainresource
#   INFO     | Parsing profile "EffectEvidenceSynthesis"
#   DEBUG    | Created class "EffectEvidenceSynthesis", module effectevidencesynthesis
#   DEBUG    | Created class "EffectEvidenceSynthesisSampleSize", module effectevidencesynthesis
#   DEBUG    | Created class "EffectEvidenceSynthesisResultsByExposure", module effectevidencesynthesis
#   DEBUG    | Created class "EffectEvidenceSynthesisEffectEstimate", module effectevidencesynthesis
#   DEBUG    | Created class "EffectEvidenceSynthesisEffectEstimatePrecisionEstimate", module effectevidencesynthesis
#   DEBUG    | Created class "EffectEvidenceSynthesisCertainty", module effectevidencesynthesis
#   DEBUG    | Created class "EffectEvidenceSynthesisCertaintyCertaintySubcomponent", module effectevidencesynthesis
#   INFO     | Parsing profile "Encounter"
#   DEBUG    | Created class "Encounter", module encounter
#   DEBUG    | Created class "EncounterStatusHistory", module encounter
#   DEBUG    | Created class "EncounterClassHistory", module encounter
#   DEBUG    | Created class "EncounterParticipant", module encounter
#   DEBUG    | Created class "EncounterDiagnosis", module encounter
#   DEBUG    | Created class "EncounterHospitalization", module encounter
#   DEBUG    | Created class "EncounterLocation", module encounter
#   INFO     | Parsing profile "Endpoint"
#   DEBUG    | Created class "Endpoint", module endpoint
#   INFO     | Parsing profile "EnrollmentRequest"
#   DEBUG    | Created class "EnrollmentRequest", module enrollmentrequest
#   INFO     | Parsing profile "EnrollmentResponse"
#   DEBUG    | Created class "EnrollmentResponse", module enrollmentresponse
#   INFO     | Parsing profile "EpisodeOfCare"
#   DEBUG    | Created class "EpisodeOfCare", module episodeofcare
#   DEBUG    | Created class "EpisodeOfCareStatusHistory", module episodeofcare
#   DEBUG    | Created class "EpisodeOfCareDiagnosis", module episodeofcare
#   INFO     | Parsing profile "EventDefinition"
#   DEBUG    | Created class "EventDefinition", module eventdefinition
#   INFO     | Parsing profile "Evidence"
#   DEBUG    | Created class "Evidence", module evidence
#   INFO     | Parsing profile "EvidenceVariable"
#   DEBUG    | Created class "EvidenceVariable", module evidencevariable
#   DEBUG    | Created class "EvidenceVariableCharacteristic", module evidencevariable
#   INFO     | Parsing profile "ExampleScenario"
#   DEBUG    | Created class "ExampleScenario", module examplescenario
#   DEBUG    | Created class "ExampleScenarioActor", module examplescenario
#   DEBUG    | Created class "ExampleScenarioInstance", module examplescenario
#   DEBUG    | Created class "ExampleScenarioInstanceVersion", module examplescenario
#   DEBUG    | Created class "ExampleScenarioInstanceContainedInstance", module examplescenario
#   DEBUG    | Created class "ExampleScenarioProcess", module examplescenario
#   DEBUG    | Created class "ExampleScenarioProcessStep", module examplescenario
#   DEBUG    | Created class "ExampleScenarioProcessStepOperation", module examplescenario
#   DEBUG    | Created class "ExampleScenarioProcessStepAlternative", module examplescenario
#   INFO     | Parsing profile "ExplanationOfBenefit"
#   DEBUG    | Created class "ExplanationOfBenefit", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitRelated", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitPayee", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitCareTeam", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitSupportingInfo", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitDiagnosis", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitProcedure", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitInsurance", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitAccident", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitItem", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitItemAdjudication", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitItemDetail", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitItemDetailSubDetail", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitAddItem", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitAddItemDetail", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitAddItemDetailSubDetail", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitTotal", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitPayment", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitProcessNote", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitBenefitBalance", module explanationofbenefit
#   DEBUG    | Created class "ExplanationOfBenefitBenefitBalanceFinancial", module explanationofbenefit
#   INFO     | Parsing profile "FamilyMemberHistory"
#   DEBUG    | Created class "FamilyMemberHistory", module familymemberhistory
#   DEBUG    | Created class "FamilyMemberHistoryCondition", module familymemberhistory
#   INFO     | Parsing profile "Flag"
#   DEBUG    | Created class "Flag", module flag
#   INFO     | Parsing profile "Goal"
#   DEBUG    | Created class "Goal", module goal
#   DEBUG    | Created class "GoalTarget", module goal
#   INFO     | Parsing profile "GraphDefinition"
#   DEBUG    | Created class "GraphDefinition", module graphdefinition
#   DEBUG    | Created class "GraphDefinitionLink", module graphdefinition
#   DEBUG    | Created class "GraphDefinitionLinkTarget", module graphdefinition
#   DEBUG    | Created class "GraphDefinitionLinkTargetCompartment", module graphdefinition
#   INFO     | Parsing profile "Group"
#   DEBUG    | Created class "Group", module group
#   DEBUG    | Created class "GroupCharacteristic", module group
#   DEBUG    | Created class "GroupMember", module group
#   INFO     | Parsing profile "GuidanceResponse"
#   DEBUG    | Created class "GuidanceResponse", module guidanceresponse
#   INFO     | Parsing profile "HealthcareService"
#   DEBUG    | Created class "HealthcareService", module healthcareservice
#   DEBUG    | Created class "HealthcareServiceEligibility", module healthcareservice
#   DEBUG    | Created class "HealthcareServiceAvailableTime", module healthcareservice
#   DEBUG    | Created class "HealthcareServiceNotAvailable", module healthcareservice
#   INFO     | Parsing profile "ImagingStudy"
#   DEBUG    | Created class "ImagingStudy", module imagingstudy
#   DEBUG    | Created class "ImagingStudySeries", module imagingstudy
#   DEBUG    | Created class "ImagingStudySeriesPerformer", module imagingstudy
#   DEBUG    | Created class "ImagingStudySeriesInstance", module imagingstudy
#   INFO     | Parsing profile "Immunization"
#   DEBUG    | Created class "Immunization", module immunization
#   DEBUG    | Created class "ImmunizationPerformer", module immunization
#   DEBUG    | Created class "ImmunizationEducation", module immunization
#   DEBUG    | Created class "ImmunizationReaction", module immunization
#   DEBUG    | Created class "ImmunizationProtocolApplied", module immunization
#   INFO     | Parsing profile "ImmunizationEvaluation"
#   DEBUG    | Created class "ImmunizationEvaluation", module immunizationevaluation
#   INFO     | Parsing profile "ImmunizationRecommendation"
#   DEBUG    | Created class "ImmunizationRecommendation", module immunizationrecommendation
#   DEBUG    | Created class "ImmunizationRecommendationRecommendation", module immunizationrecommendation
#   DEBUG    | Created class "ImmunizationRecommendationRecommendationDateCriterion", module immunizationrecommendation
#   INFO     | Parsing profile "ImplementationGuide"
#   DEBUG    | Created class "ImplementationGuide", module implementationguide
#   DEBUG    | Created class "ImplementationGuideDependsOn", module implementationguide
#   DEBUG    | Created class "ImplementationGuideGlobal", module implementationguide
#   DEBUG    | Created class "ImplementationGuideDefinition", module implementationguide
#   DEBUG    | Created class "ImplementationGuideDefinitionGrouping", module implementationguide
#   DEBUG    | Created class "ImplementationGuideDefinitionResource", module implementationguide
#   DEBUG    | Created class "ImplementationGuideDefinitionPage", module implementationguide
#   DEBUG    | Created class "ImplementationGuideDefinitionParameter", module implementationguide
#   DEBUG    | Created class "ImplementationGuideDefinitionTemplate", module implementationguide
#   DEBUG    | Created class "ImplementationGuideManifest", module implementationguide
#   DEBUG    | Created class "ImplementationGuideManifestResource", module implementationguide
#   DEBUG    | Created class "ImplementationGuideManifestPage", module implementationguide
#   INFO     | Parsing profile "InsurancePlan"
#   DEBUG    | Created class "InsurancePlan", module insuranceplan
#   DEBUG    | Created class "InsurancePlanContact", module insuranceplan
#   DEBUG    | Created class "InsurancePlanCoverage", module insuranceplan
#   DEBUG    | Created class "InsurancePlanCoverageBenefit", module insuranceplan
#   DEBUG    | Created class "InsurancePlanCoverageBenefitLimit", module insuranceplan
#   DEBUG    | Created class "InsurancePlanPlan", module insuranceplan
#   DEBUG    | Created class "InsurancePlanPlanGeneralCost", module insuranceplan
#   DEBUG    | Created class "InsurancePlanPlanSpecificCost", module insuranceplan
#   DEBUG    | Created class "InsurancePlanPlanSpecificCostBenefit", module insuranceplan
#   DEBUG    | Created class "InsurancePlanPlanSpecificCostBenefitCost", module insuranceplan
#   INFO     | Parsing profile "Invoice"
#   DEBUG    | Created class "Invoice", module invoice
#   DEBUG    | Created class "InvoiceParticipant", module invoice
#   DEBUG    | Created class "InvoiceLineItem", module invoice
#   DEBUG    | Created class "InvoiceLineItemPriceComponent", module invoice
#   INFO     | Parsing profile "Library"
#   DEBUG    | Created class "Library", module library
#   INFO     | Parsing profile "Linkage"
#   DEBUG    | Created class "Linkage", module linkage
#   DEBUG    | Created class "LinkageItem", module linkage
#   INFO     | Parsing profile "List"
#   DEBUG    | Created class "List", module list
#   DEBUG    | Created class "ListEntry", module list
#   INFO     | Parsing profile "Location"
#   DEBUG    | Created class "Location", module location
#   DEBUG    | Created class "LocationPosition", module location
#   DEBUG    | Created class "LocationHoursOfOperation", module location
#   INFO     | Parsing profile "Measure"
#   DEBUG    | Created class "Measure", module measure
#   DEBUG    | Created class "MeasureGroup", module measure
#   DEBUG    | Created class "MeasureGroupPopulation", module measure
#   DEBUG    | Created class "MeasureGroupStratifier", module measure
#   DEBUG    | Created class "MeasureGroupStratifierComponent", module measure
#   DEBUG    | Created class "MeasureSupplementalData", module measure
# ...
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/auditevent_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/media_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/testscript_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicinalproductcontraindication_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/list_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/schedule_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/valueset_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/careplan_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/nutritionorder_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/procedure_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/eventdefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/appointmentresponse_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/measurereport_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/operationoutcome_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/immunizationevaluation_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/servicerequest_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/encounter_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/organization_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/riskevidencesynthesis_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/parameters_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/messageheader_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/appointment_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/substance_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/codesystem_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/devicemetric_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/documentmanifest_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/condition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/coverage_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/devicerequest_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/implementationguide_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicinalproductmanufactured_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/searchparameter_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/task_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/riskassessment_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicinalproductinteraction_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/specimendefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/group_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/imagingstudy_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/person_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/endpoint_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/immunization_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/slot_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/binary_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/detectedissue_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/relatedperson_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/provenance_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/linkage_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/specimen_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/practitioner_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/activitydefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicinalproduct_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/communicationrequest_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/clinicalimpression_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/allergyintolerance_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/catalogentry_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/careteam_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/biologicallyderivedproduct_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/location_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/bodystructure_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/measure_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/basic_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/explanationofbenefit_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/communication_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/terminologycapabilities_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/conceptmap_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicinalproductpharmaceutical_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/capabilitystatement_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/device_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/chargeitemdefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/organizationaffiliation_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicinalproductpackaged_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/questionnaireresponse_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/messagedefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/immunizationrecommendation_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/invoice_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/visionprescription_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/coverageeligibilityrequest_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/verificationresult_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/library_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/examplescenario_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/questionnaire_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/diagnosticreport_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/namingsystem_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicinalproductindication_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicinalproductundesirableeffect_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/flag_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/insuranceplan_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/researchdefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/account_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/structuredefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/composition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/enrollmentresponse_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/supplyrequest_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/episodeofcare_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/researchstudy_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicationknowledge_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/subscription_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/evidencevariable_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/paymentreconciliation_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/requestgroup_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/effectevidencesynthesis_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/chargeitem_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/researchelementdefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/graphdefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/devicedefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/practitionerrole_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/evidence_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/deviceusestatement_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/operationdefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/guidanceresponse_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicinalproductauthorization_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/documentreference_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/observationdefinition_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/structuremap_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/adverseevent_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/medicinalproductingredient_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/enrollmentrequest_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/supplydelivery_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/researchsubject_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/healthcareservice_tests.py
#   INFO     | Writing /Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/tests/model/paymentnotice_tests.py

# %% [markdown]
# ## <a id='3_cell'></a>3. Now That We Created the Python Models Lets Use Them:

# %%
cd ~/pyFHIR_models

# %% [markdown]
# ### Import a model:

# %%
from fhir_model_generator.model import patient as P
P
# Out:
# <module 'fhir_model_generator.model.patient' from '/Users/ehaas/Documents/Python/MyBinder/pyFHIR_models/fhir_model_generator/model/patient.py'>

# %% [markdown]
# ### Add some other modules from the Python Standard Library:

# %%
from json import dumps,loads  # to convert to and from json
from requests import get, post  # to validate
from IPython.display import display as Display, HTML, Markdown

# %% [markdown]
# ### Create a patient instance:

# %%
my_patient = P.Patient()
my_patient
# Out:
# Patient(id=None, meta=None, implicitRules=None, language=None, text=None, contained=None, extension=None, modifierExtension=None, identifier=None, active=None, name=None, telecom=None, gender=None, birthDate=None, deceasedBoolean=None, deceasedDateTime=None, address=None, maritalStatus=None, multipleBirthBoolean=None, multipleBirthInteger=None, photo=None, contact=None, communication=None, generalPractitioner=None, managingOrganization=None, link=None)

# %% [markdown]
# ### Documentation for Model

# %%
help(my_patient)
# Out:
# Help on Patient in module fhir_model_generator.model.patient object:
#
# class Patient(fhir_model_generator.model.domainresource.DomainResource)
#  |  Patient(jsondict: dataclasses.InitVar = None, strict: dataclasses.InitVar = True, id: Union[str, NoneType] = None, meta: Union[fhir_model_generator.model.meta.Meta, NoneType] = None, implicitRules: Union[str, NoneType] = None, language: Union[str, NoneType] = None, text: Union[fhir_model_generator.model.narrative.Narrative, NoneType] = None, contained: Union[List[fhir_model_generator.model.resource.Resource], NoneType] = None, extension: Union[List[fhir_model_generator.model.extension.Extension], NoneType] = None, modifierExtension: Union[List[fhir_model_generator.model.extension.Extension], NoneType] = None, identifier: Union[List[fhir_model_generator.model.identifier.Identifier], NoneType] = None, active: Union[bool, NoneType] = None, name: Union[List[fhir_model_generator.model.humanname.HumanName], NoneType] = None, telecom: Union[List[fhir_model_generator.model.contactpoint.ContactPoint], NoneType] = None, gender: Union[str, NoneType] = None, birthDate: Union[fhir_model_generator.model.fhirdate.FHIRDate, NoneType] = None, deceasedBoolean: Union[bool, NoneType] = None, deceasedDateTime: Union[fhir_model_generator.model.fhirdate.FHIRDate, NoneType] = None, address: Union[List[fhir_model_generator.model.address.Address], NoneType] = None, maritalStatus: Union[fhir_model_generator.model.codeableconcept.CodeableConcept, NoneType] = None, multipleBirthBoolean: Union[bool, NoneType] = None, multipleBirthInteger: Union[int, NoneType] = None, photo: Union[List[fhir_model_generator.model.attachment.Attachment], NoneType] = None, contact: Union[List[fhir_model_generator.model.patient.PatientContact], NoneType] = None, communication: Union[List[fhir_model_generator.model.patient.PatientCommunication], NoneType] = None, generalPractitioner: Union[List[fhir_model_generator.model.fhirreference.FHIRReference], NoneType] = None, managingOrganization: Union[fhir_model_generator.model.fhirreference.FHIRReference, NoneType] = None, link: Union[List[fhir_model_generator.model.patient.PatientLink], NoneType] = None) -> None
#  |
#  |  Information about an individual or animal receiving health care services.
#  |
#  |  Demographics and other administrative information about an individual or
#  |  animal receiving care or other health-related services.
#  |
#  |  Method resolution order:
#  |      Patient
#  |      fhir_model_generator.model.domainresource.DomainResource
#  |      fhir_model_generator.model.resource.Resource
#  |      fhir_model_generator.model.fhirabstractresource.FHIRAbstractResource
#  |      fhir_model_generator.model.fhirabstractbase.FHIRAbstractBase
#  |      builtins.object
#  |
#  |  Methods defined here:
#  |
#  |  __eq__(self, other)
#  |
#  |  __init__(self, jsondict: dataclasses.InitVar = None, strict: dataclasses.InitVar = True, id: Union[str, NoneType] = None, meta: Union[fhir_model_generator.model.meta.Meta, NoneType] = None, implicitRules: Union[str, NoneType] = None, language: Union[str, NoneType] = None, text: Union[fhir_model_generator.model.narrative.Narrative, NoneType] = None, contained: Union[List[fhir_model_generator.model.resource.Resource], NoneType] = None, extension: Union[List[fhir_model_generator.model.extension.Extension], NoneType] = None, modifierExtension: Union[List[fhir_model_generator.model.extension.Extension], NoneType] = None, identifier: Union[List[fhir_model_generator.model.identifier.Identifier], NoneType] = None, active: Union[bool, NoneType] = None, name: Union[List[fhir_model_generator.model.humanname.HumanName], NoneType] = None, telecom: Union[List[fhir_model_generator.model.contactpoint.ContactPoint], NoneType] = None, gender: Union[str, NoneType] = None, birthDate: Union[fhir_model_generator.model.fhirdate.FHIRDate, NoneType] = None, deceasedBoolean: Union[bool, NoneType] = None, deceasedDateTime: Union[fhir_model_generator.model.fhirdate.FHIRDate, NoneType] = None, address: Union[List[fhir_model_generator.model.address.Address], NoneType] = None, maritalStatus: Union[fhir_model_generator.model.codeableconcept.CodeableConcept, NoneType] = None, multipleBirthBoolean: Union[bool, NoneType] = None, multipleBirthInteger: Union[int, NoneType] = None, photo: Union[List[fhir_model_generator.model.attachment.Attachment], NoneType] = None, contact: Union[List[fhir_model_generator.model.patient.PatientContact], NoneType] = None, communication: Union[List[fhir_model_generator.model.patient.PatientCommunication], NoneType] = None, generalPractitioner: Union[List[fhir_model_generator.model.fhirreference.FHIRReference], NoneType] = None, managingOrganization: Union[fhir_model_generator.model.fhirreference.FHIRReference, NoneType] = None, link: Union[List[fhir_model_generator.model.patient.PatientLink], NoneType] = None) -> None
#  |
#  |  __repr__(self)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes defined here:
#  |
#  |  __annotations__ = {'active': typing.Union[bool, NoneType], 'address': ...
#  |
#  |  __dataclass_fields__ = {'active': Field(name='active',type=typing.Unio...
#  |
#  |  __dataclass_params__ = _DataclassParams(init=True,repr=True,eq=True,or...
#  |
#  |  __hash__ = None
#  |
#  |  active = None
#  |
#  |  address = None
#  |
#  |  birthDate = None
#  |
#  |  communication = None
#  |
#  |  contact = None
#  |
#  |  deceasedBoolean = None
#  |
#  |  deceasedDateTime = None
#  |
#  |  gender = None
#  |
#  |  generalPractitioner = None
#  |
#  |  identifier = None
#  |
#  |  link = None
#  |
#  |  managingOrganization = None
#  |
#  |  maritalStatus = None
#  |
#  |  multipleBirthBoolean = None
#  |
#  |  multipleBirthInteger = None
#  |
#  |  name = None
#  |
#  |  photo = None
#  |
#  |  resource_type = 'Patient'
#  |
#  |  telecom = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from fhir_model_generator.model.domainresource.DomainResource:
#  |
#  |  contained = None
#  |
#  |  extension = None
#  |
#  |  modifierExtension = None
#  |
#  |  text = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from fhir_model_generator.model.resource.Resource:
#  |
#  |  id = None
#  |
#  |  implicitRules = None
#  |
#  |  language = None
#  |
#  |  meta = None
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from fhir_model_generator.model.fhirabstractresource.FHIRAbstractResource:
#  |
#  |  as_json(self)
#  |      Serializes to JSON by inspecting `elementProperties()` and creating
#  |      a JSON dictionary of all registered properties. Checks:
#  |
#  |      - whether required properties are not None (and lists not empty)
#  |      - whether not-None properties are of the correct type
#  |
#  |      :raises: FHIRValidationError if properties have the wrong type or if
#  |          required properties are empty
#  |      :returns: A validated dict object that can be JSON serialized
#  |
#  |  create(self, server)
#  |      Attempt to create the receiver on the given server, using a POST
#  |      command.
#  |
#  |      :param FHIRServer server: The server to create the receiver on
#  |      :returns: None or the response JSON on success
#  |
#  |  delete(self, server=None)
#  |      Delete the receiver from the given server with a DELETE command.
#  |
#  |      :param FHIRServer server: The server to update the receiver on;
#  |          optional, will use the instance's `server` if needed.
#  |      :returns: None or the response JSON on success
#  |
#  |  relativeBase(self)
#  |
#  |  relativePath(self)
#  |
#  |  search(self, struct=None)
#  |      Search can be started via a dictionary containing a search
#  |      construct.
#  |
#  |      Calling this method with a search struct will return a `FHIRSearch`
#  |      object representing the search struct, with "$type" and "id" added.
#  |
#  |      :param dict struct: An optional search structure
#  |      :returns: A FHIRSearch instance
#  |
#  |  update(self, server=None)
#  |      Update the receiver's representation on the given server, issuing
#  |      a PUT command.
#  |
#  |      :param FHIRServer server: The server to update the receiver on;
#  |          optional, will use the instance's `server` if needed.
#  |      :returns: None or the response JSON on success
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from fhir_model_generator.model.fhirabstractresource.FHIRAbstractResource:
#  |
#  |  read(rem_id, server) from builtins.type
#  |      Read the resource with the given id from the given server. The
#  |      passed-in server instance must support a `request_json()` method call,
#  |      taking a relative path as first (and only mandatory) argument.
#  |
#  |      :param str rem_id: The id of the resource on the remote server
#  |      :param FHIRServer server: An instance of a FHIR server or compatible class
#  |      :returns: An instance of the receiving class
#  |
#  |  read_from(path, server) from builtins.type
#  |      Requests data from the given REST path on the server and creates
#  |      an instance of the receiving class.
#  |
#  |      :param str path: The REST path to read from
#  |      :param FHIRServer server: An instance of a FHIR server or compatible class
#  |      :returns: An instance of the receiving class
#  |
#  |  where(struct) from builtins.type
#  |      Search can be started via a dictionary containing a search
#  |      construct.
#  |
#  |      Calling this method with a search struct will return a `FHIRSearch`
#  |      object representing the search struct
#  |
#  |      :param dict struct: A search structure
#  |      :returns: A FHIRSearch instance
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from fhir_model_generator.model.fhirabstractresource.FHIRAbstractResource:
#  |
#  |  origin_server
#  |      Walks the owner hierarchy until it finds an owner with a server.
#  |
#  |  ----------------------------------------------------------------------
#  |  Methods inherited from fhir_model_generator.model.fhirabstractbase.FHIRAbstractBase:
#  |
#  |  __post_init__(self, jsondict, strict)
#  |      Initializer. If strict is true, raises on errors, otherwise uses
#  |      `logger.warning()`.
#  |
#  |      :raises: FHIRValidationError on validation errors, unless strict is False
#  |      :param dict jsondict: A JSON dictionary to use for initialization
#  |      :param bool strict: If True (the default), invalid variables will raise a TypeError
#  |
#  |  didResolveReference(self, refid, resolved)
#  |      Called by `FHIRResource` when it resolves a reference. Stores the
#  |      resolved reference into the `_resolved` dictionary.
#  |
#  |      :param refid: The id of the resource that was resolved
#  |      :param refid: The resolved resource, ready to be cached
#  |
#  |  owningBundle(self)
#  |      Walks the owner hierarchy and returns the next parent that is a
#  |      `Bundle` instance.
#  |
#  |  owningResource(self)
#  |      Walks the owner hierarchy and returns the next parent that is a
#  |      `DomainResource` instance.
#  |
#  |  resolvedReference(self, refid)
#  |      Returns the resolved reference with the given id, if it has been
#  |      resolved already. If it hasn't, forwards the call to its owner if it
#  |      has one.
#  |
#  |      You should probably use `resolve()` on the `FHIRReference` itself.
#  |
#  |      :param refid: The id of the resource to resolve
#  |      :returns: An instance of `Resource`, if it was found
#  |
#  |  update_with_json(self, jsondict)
#  |      Update the receiver with data in a JSON dictionary.
#  |
#  |      :raises: FHIRValidationError on validation errors
#  |      :param dict jsondict: The JSON dictionary to use to update the receiver
#  |      :returns: None on success, a list of errors if there were errors
#  |
#  |  ----------------------------------------------------------------------
#  |  Class methods inherited from fhir_model_generator.model.fhirabstractbase.FHIRAbstractBase:
#  |
#  |  with_json(jsonobj) from builtins.type
#  |      Initialize an element from a JSON dictionary or array.
#  |
#  |      If the JSON dictionary has a "resourceType" entry and the specified
#  |      resource type is not the receiving classes type, uses
#  |      `FHIRElementFactory` to return a correct class instance.
#  |
#  |      :raises: TypeError on anything but dict or list of dicts
#  |      :raises: FHIRValidationError if instantiation fails
#  |      :param jsonobj: A dict or list of dicts to instantiate from
#  |      :returns: An instance or a list of instances created from JSON data
#  |
#  |  with_json_and_owner(jsonobj, owner) from builtins.type
#  |      Instantiates by forwarding to `with_json()`, then remembers the
#  |      "owner" of the instantiated elements. The "owner" is the resource
#  |      containing the receiver and is used to resolve contained resources.
#  |
#  |      :raises: TypeError on anything but dict or list of dicts
#  |      :raises: FHIRValidationError if instantiation fails
#  |      :param dict jsonobj: Decoded JSON dictionary (or list thereof)
#  |      :param FHIRElement owner: The owning parent
#  |      :returns: An instance or a list of instances created from JSON data
#  |
#  |  ----------------------------------------------------------------------
#  |  Data descriptors inherited from fhir_model_generator.model.fhirabstractbase.FHIRAbstractBase:
#  |
#  |  __dict__
#  |      dictionary for instance variables (if defined)
#  |
#  |  __weakref__
#  |      list of weak references to the object (if defined)
#  |
#  |  ----------------------------------------------------------------------
#  |  Data and other attributes inherited from fhir_model_generator.model.fhirabstractbase.FHIRAbstractBase:
#  |
#  |  jsondict = None
#  |
#  |  strict = True

# %% [markdown]
# ### Populate the gender element:

# %%
my_patient.gender = 'male'
my_patient
# Out:
# Patient(id=None, meta=None, implicitRules=None, language=None, text=None, contained=None, extension=None, modifierExtension=None, identifier=None, active=None, name=None, telecom=None, gender='male', birthDate=None, deceasedBoolean=None, deceasedDateTime=None, address=None, maritalStatus=None, multipleBirthBoolean=None, multipleBirthInteger=None, photo=None, contact=None, communication=None, generalPractitioner=None, managingOrganization=None, link=None)

# %% [markdown]
# ### Add a name to the Patient
#
# 1. instantiate the HumanName Datatype
# 1. populate the HumanName Elements
# 1. populate the Patient Resource with the name element

# %%
from fhir_model_generator.model import humanname as H
my_name = H.HumanName()
my_name
# Out:
# HumanName(id=None, extension=None, use=None, text=None, family=None, given=None, prefix=None, suffix=None, period=None)

# %%
my_name.family = 'Haas'
my_name.given = ['Eric']
my_name.text = f"{my_name.given[0]} {my_name.family}"
my_name
# Out:
# HumanName(id=None, extension=None, use=None, text='Eric Haas', family='Haas', given=['Eric'], prefix=None, suffix=None, period=None)

# %%
my_patient.name = [my_name]
my_patient
# Out:
# Patient(id=None, meta=None, implicitRules=None, language=None, text=None, contained=None, extension=None, modifierExtension=None, identifier=None, active=None, name=[HumanName(id=None, extension=None, use=None, text='Eric Haas', family='Haas', given=['Eric'], prefix=None, suffix=None, period=None)], telecom=None, gender='male', birthDate=None, deceasedBoolean=None, deceasedDateTime=None, address=None, maritalStatus=None, multipleBirthBoolean=None, multipleBirthInteger=None, photo=None, contact=None, communication=None, generalPractitioner=None, managingOrganization=None, link=None)

# %% [markdown]
# ### Convert to dict

# %%
my_patient.as_json()
# Out:
# OrderedDict([('resourceType', 'Patient'),
#              ('name',
#               [{'text': 'Eric Haas', 'family': 'Haas', 'given': ['Eric']}]),
#              ('gender', 'male')])

# %% [markdown]
# ### Convert to JSON

# %%
my_pj = dumps(my_patient.as_json(), indent = 4)
print(my_pj)
# Out:
# {
#     "resourceType": "Patient",
#     "name": [
#         {
#             "text": "Eric Haas",
#             "family": "Haas",
#             "given": [
#                 "Eric"
#             ]
#         }
#     ],
#     "gender": "male"
# }

# %% [markdown]
# ### Validate Using Test Server and `$validate` Operation

# %%
# ref_server = 'http://test.fhir.org/r4'
ref_server ='http://hapi.fhir.org/baseR4'
headers = {
    'Accept':'application/fhir+json',
    'Content-Type':'application/fhir+json'
    }
params = dict(
      )
print('validating ...')
r = post(f'{ref_server}/{my_patient.resource_type}/$validate', params = params, headers = headers, data = my_pj)
display(HTML(
    '<h1>Validation output</h1>'
    f'<h3>Status Code = {r.status_code}</h3>'
    f'{r.json()["text"]["div"]}'
    ))
# Out:
# validating ...
# <h1>Validation output</h1><h3>Status Code = 200</h3><div xmlns="http://www.w3.org/1999/xhtml"><h1>Operation Outcome</h1><table border="0"><tr><td style="font-weight: bold;">WARNING</td><td>[Patient, Line 1, Col 2]</td><td><pre>dom-6: A resource should have narrative for robust management [text.div.exists()]</pre></td>
#
#
# 			</tr>
# 		</table>
# 	</div>
